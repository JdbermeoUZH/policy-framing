# %%
import os

import mlflow
from mlflow import log_metric, log_param, MlflowClient
from mlflow.entities import ViewType
from IPython.display import display, Markdown
import pandas as pd

# %% [markdown]
# ## Get list of experiments

# %%
exp_ids = os.listdir('./mlruns')

# %%
len(exp_ids)
# Out:
# 2009

# %% [markdown]
# # Model Wide Metrics

# %% [markdown]
# ## Loop over experiments, and get their model wide metrics
#
# Extract the following things
#
#  - Name of the experiment
#  - Model type it belongs to
#  - metrics
#  - run name

# %%
client =  MlflowClient()
analysis_level = 'model_wide'
query = f"params.analysis_level = '{analysis_level}'"

# %% [markdown]
# Retrieve all metrics and params of 'model_wide' runs and save it in a csv file

# %%
rows = []
for exp_i, exp_id in enumerate(exp_ids):
    # Retrieve 'model_wide' runs of the experiment
    try:
        runs = client.search_runs(experiment_ids=exp_id, filter_string=query)
    except:
        print(f'problems with exp_id: {exp_id} in position {exp_i}')
        continue
        
    # Add relevant parameters to the row
    for run in runs:
        row_dict = {'exp_id': exp_id, 'run_uuid': run.info.run_uuid, 'runName': run.data.tags['mlflow.runName'],
                    **run.data.metrics, **run.data.params}
        rows.append(row_dict)
        
    if exp_i % 100 == 0 and exp_i!=0:
        pd.DataFrame(rows).set_index(['run_uuid', 'model_name', 'runName']).sort_index().to_csv('all_model_wide_results.csv')
    
pd.DataFrame(rows).set_index(['run_uuid', 'model_name', 'runName']).sort_index().to_csv('all_model_wide_results.csv')
# Out:
# problems with exp_id: 168812780760165522 in position 1942

# %% [markdown]
# ## Group types of models (experiment type and model type) and pick best performing in terms of f1-score per unit of analysis
#
#  * Create dictionary for experiment types and model types
#  * Create to dataframes (for each of the previous groups) and pick the ones with max test_f1_score

# %%
mw_df = pd.read_csv('all_model_wide_results.csv', index_col=['run_uuid', 'model_name', 'runName'])

# %%
m = {
    'Naive Bayes': ['NaiveBayes',
                     'NaiveBayes_BorderlineSMOTE_v1',
                     'NaiveBayes_BorderlineSMOTE_v2',
                     'NaiveBayes_BorderlineSMOTE_v3',
                     'NaiveBayes_ROS_v1',
                     'NaiveBayes_ROS_v2',
                     'NaiveBayes_SMOTE_v1',
                     'NaiveBayes_SMOTE_v2',
                     'NaiveBayes_SMOTE_v3',],
    
    'Complement Naive Bayes': ['ComplementNaiveBayes',
                              'ComplementNaiveBayes_BorderlineSMOTE_v1',
                              'ComplementNaiveBayes_BorderlineSMOTE_v2',
                              'ComplementNaiveBayes_BorderlineSMOTE_v3',
                              'ComplementNaiveBayes_ROS_v1',
                              'ComplementNaiveBayes_SMOTE_v1',
                              'ComplementNaiveBayes_SMOTE_v2'],
     
     'LogisticRegression': ['LogisticRegression',
                           'LogisticRegression_BorderlineSMOTE',
                             'LogisticRegression_BorderlineSMOTE_v2',
                             'LogisticRegression_ROS_v1',
                             'LogisticRegression_ROS_v2',
                             'LogisticRegression_ROS_v3',
                             'LogisticRegression_SMOTE',
                             'LogisticRegression_SMOTE_v2',
                             'LogisticRegression_SVMSMOTE',
                             'LogisticRegression_SVMSMOTE_v2'],
     
     'Logistic Regression Lasso': ['LogisticRegressionLassoV1',
                                     'LogisticRegressionLassoV2',
                                     'LogisticRegressionLasso_BorderlineSMOTE_v1',
                                     'LogisticRegressionLasso_BorderlineSMOTE_v2',
                                     'LogisticRegressionLasso_BorderlineSMOTE_v3',
                                     'LogisticRegressionLasso_SMOTE_v1',
                                     'LogisticRegressionLasso_SMOTE_v2',
                                     'LogisticRegressionLasso_SMOTE_v3',
                                     'LogisticRegressionLasso_SVMSMOTE_v1',],
     
     'Logistic Regression ElasticNet': ['LogisticRegressionElasticNetV1',
                                        'LogisticRegressionElasticNetV2',
                                        'LogisticRegressionElasticNetV3',
                                         'LogisticRegressionElasticNet_BorderlineSMOTE_v1',
                                         'LogisticRegressionElasticNet_BorderlineSMOTE_v2',
                                         'LogisticRegressionElasticNet_BorderlineSMOTE_v3',
                                         'LogisticRegressionElasticNet_ROS_v1',
                                         'LogisticRegressionElasticNet_ROS_v2',
                                         'LogisticRegressionElasticNet_ROS_v3',
                                         'LogisticRegressionElasticNet_SMOTE_v1',
                                         'LogisticRegressionElasticNet_SMOTE_v2',
                                         'LogisticRegressionElasticNet_SMOTE_v3',
                                         'LogisticRegressionElasticNet_SVMSMOTE_v1',
                                         'LogisticRegressionElasticNet_SVMSMOTE_v2',
                                         'LogisticRegressionElasticNet_SVMSMOTE_v3'],
     
     'Logistic Regression Ridge': ['LogisticRegressionRidgeDual',
                                     'LogisticRegressionRidgeDual_BorderlineSMOTE_v1',
                                     'LogisticRegressionRidgeDual_BorderlineSMOTE_v2',
                                     'LogisticRegressionRidgeDual_BorderlineSMOTE_v3',
                                     'LogisticRegressionRidgeDual_ROS_v1',
                                     'LogisticRegressionRidgeDual_SMOTE_v1',
                                     'LogisticRegressionRidgeDual_SMOTE_v2',
                                     'LogisticRegressionRidgeDual_SMOTE_v3',
                                     'LogisticRegressionRidgeDual_SVMSMOTE_v1',
                                     'LogisticRegressionRidgeDual_SVMSMOTE_v2',
                                     'LogisticRegressionRidgeDual_SVMSMOTE_v3',
                                     'LogisticRegressionRidgeV1',
                                     'LogisticRegressionRidgeV2',
                                     'LogisticRegressionRidge_BorderlineSMOTE_v1',
                                     'LogisticRegressionRidge_BorderlineSMOTE_v2',
                                     'LogisticRegressionRidge_BorderlineSMOTE_v3',
                                     'LogisticRegressionRidge_ROS_v1',
                                     'LogisticRegressionRidge_ROS_v2',
                                     'LogisticRegressionRidge_ROS_v3',
                                     'LogisticRegressionRidge_SMOTE_v1',
                                     'LogisticRegressionRidge_SMOTE_v2',
                                     'LogisticRegressionRidge_SMOTE_v3',
                                     'LogisticRegressionRidge_SVMSMOTE_v1',
                                     'LogisticRegressionRidge_SVMSMOTE_v2',
                                     'LogisticRegressionRidge_SVMSMOTE_v3'],
    
    'RidgeClassifier' :['RidgeClassifierV1',
                         'RidgeClassifierV2',
                         'RidgeClassifier_BorderlineSMOTE_v1',
                         'RidgeClassifier_BorderlineSMOTE_v2',
                         'RidgeClassifier_BorderlineSMOTE_v3',
                         'RidgeClassifier_ROS_v1',
                         'RidgeClassifier_ROS_v2',
                         'RidgeClassifier_ROS_v3',
                         'RidgeClassifier_SMOTE_v1',
                         'RidgeClassifier_SMOTE_v2',
                         'RidgeClassifier_SMOTE_v3',
                         'RidgeClassifier_SVMSMOTE_v1',
                         'RidgeClassifier_SVMSMOTE_v2',
                         'RidgeClassifier_SVMSMOTE_v3',],
    
    
    'SVM': ['SVM_rbf_BorderlineSMOTE_v1',
             'SVM_rbf_BorderlineSMOTE_v2',
             'SVM_rbf_BorderlineSMOTE_v3',
             'SVM_rbf_ROS_v1',
             'SVM_rbf_ROS_v2',
             'SVM_rbf_ROS_v3',
             'SVM_rbf_SMOTE_v1',
             'SVM_rbf_SMOTE_v2',
             'SVM_rbf_SMOTE_v3',
             'SVM_rbf_V1',
             'SVM_rbf_V2',
             'SVM_rbf_V3',
             'SVM_rbf_V4',
             'SVM_sigmoid_ROS_v1',
             'SVM_sigmoid_ROS_v2',
             'SVM_sigmoid_V3',
             'SVM_sigmoid_V4',
             'SVM_sigmoid_broader_gamma',
             'SVM_sigmoid_narrow_gamma',],
    
    'Random Forest': ['RandomForestSK_V1',
                     'RandomForestSK_V2',
                     'RandomForestSK_V3',
                     'RandomForest_BorderlineSMOTE_v0',
                     'RandomForest_BorderlineSMOTE_v1',
                     'RandomForest_BorderlineSMOTE_v2',
                     'RandomForest_BorderlineSMOTE_v3',
                     'RandomForest_ROS_v0',
                     'RandomForest_ROS_v1',
                     'RandomForest_ROS_v2',
                     'RandomForest_ROS_v3',
                     'RandomForest_SMOTE_v0',
                     'RandomForest_SMOTE_v1',
                     'RandomForest_SMOTE_v2',
                     'RandomForest_SMOTE_v3',],
    
    'XGBoost': [ 'XGBoost_broad_BorderlineSMOTE',
                 'XGBoost_broad_ROS',
                 'XGBoost_broad_SMOTE',
                 'XGBoost_broad_SVMSMOTE',
                 'XGBoost_narrow_BorderlineSMOTE',
                 'XGBoost_narrow_ROS',
                 'XGBoost_narrow_SMOTE',
                 'XGBoost_narrow_SVMSMOTE']
     
    }

recode_dict = {v: k for k,vv in m.items() for v in vv}

# %%
mw_df['model_type'] = mw_df.index.get_level_values(1).map(recode_dict)

# %%
best_models_df = mw_df.reset_index().loc[mw_df.reset_index().groupby(['model_type', 'unit_of_analysis'])['test_f1_micro_mean'].idxmax()]\
    .set_index(['model_type', 'unit_of_analysis'])
# Out:
#                                                                                                 run_uuid  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                 975db7d9d8944a51b21f06b77b4f3b60
#                                title                                    35312937e998481ebf8d6a8c7e1a5d88
#                                title_and_10_sentences                   54184d6e3c304c56856fb85ed82d95fc
#                                title_and_5_sentences                    21b61557bb104a94be5ca70a021d95af
#                                title_and_first_paragraph                7467af49fff94e71b7cdfcb5a7b8d2c4
#                                title_and_first_sentence_each_paragraph  3e59f64df8bc4c3199605be1c144dd46
# Logistic Regression ElasticNet raw_text                                 f580a57de7c14c30a237ad46ae271dd4
#                                title                                    28a85e5540f443d79e40bfca4b20e4f8
#                                title_and_10_sentences                   ee36956330ae4165818b3c821a036e86
#                                title_and_5_sentences                    1dacdf3ed85a4ea9a5436b3894a70a85
#                                title_and_first_paragraph                129239fd06f743ac9376aab677c472c8
#                                title_and_first_sentence_each_paragraph  1c980fd7dba7426fb16086b56bf8473b
# Logistic Regression Lasso      raw_text                                 86a3b47f5c084125b8cac96b1e499e33
#                                title                                    3cc9c9e467ad48fd92f7625a0a1ac0cd
#                                title_and_10_sentences                   ef11b0e3ef3c4ac186045c66440a73a1
#                                title_and_5_sentences                    2173a1970f87487fae76c56ceaa21c49
#                                title_and_first_paragraph                9dcbd608e26649cf9fc6fdf36ad21abc
#                                title_and_first_sentence_each_paragraph  0fe79e0eac964fa19e85c90d4d90db8a
# Logistic Regression Ridge      raw_text                                 d764dc8a1e9748299676e4f91b4e9253
#                                title                                    2c7e3eed5088433dba7655c715d663ab
#                                title_and_10_sentences                   e51e256d3b2b46a8923c64f053ba4717
#                                title_and_5_sentences                    aa469616562b471b9a6dc88f24062c67
#                                title_and_first_paragraph                136f6cb479ba43e6b5c68a1701820d1c
#                                title_and_first_sentence_each_paragraph  244536dbc9f742f7b330413891733757
# LogisticRegression             raw_text                                 2f8cc9dfc08b4caa822f51d130da6f37
#                                title                                    39402c2a0218452c9793dfbba849080b
#                                title_and_10_sentences                   720d89a116b84bdcb295f90209c6453d
#                                title_and_5_sentences                    4d170ce6b00542ff878b7de3339d1ee8
#                                title_and_first_paragraph                f9c1a5e263674371a9987aedc7097e38
#                                title_and_first_sentence_each_paragraph  b47f9932608f42cfb1e09baa15de0c0e
# Naive Bayes                    raw_text                                 434f6b87ae064ed58dc4ab4291982053
#                                title                                    ea4c485a80cb49989be9d646cf7743d6
#                                title_and_10_sentences                   920c4d857b004fb284aa27b96bf9493f
#                                title_and_5_sentences                    5c02966b514240949c205859c297bfe4
#                                title_and_first_paragraph                041761de4b6848b3927df6ca7bdcd0cd
#                                title_and_first_sentence_each_paragraph  64cc750ad5b9427b8281dc84d0ec42a1
# Random Forest                  raw_text                                 a9f08b77376d45338e0bc018679980f0
#                                title                                    1c3a8077acf74b268653ce77b441eebe
#                                title_and_10_sentences                   97bacacf8d3f408fb7f7e5eac70392c6
#                                title_and_5_sentences                    e63856e987bf493a923786e89e8c97cf
#                                title_and_first_paragraph                55d201eb803b465989ca923d2fa573f5
#                                title_and_first_sentence_each_paragraph  549349d09a644bff872317a8f26a031e
# RidgeClassifier                raw_text                                 a0ea16474898441f97970c2c5e25d62f
#                                title                                    fb7356bbcc4d45b3947dcb8f5208d1bd
#                                title_and_10_sentences                   32bd169aee764ccebc5feff2f75dca3a
#                                title_and_5_sentences                    0ad69620be25402ab7ce90ba2b7a01f8
#                                title_and_first_paragraph                89c9875fb253431b9b52db72d4c81e62
#                                title_and_first_sentence_each_paragraph  21cd99ac5f114aa0b133e91e660bbab4
# SVM                            title                                    704ea5a3f94a42549214660bee03993e
# XGBoost                        raw_text                                 e732dfef22864e5195b729b44ce6a0d5
#                                title                                    a86c56ab04384b548cf1c818a4e5bc21
#                                title_and_10_sentences                   eb0d401e2a274c50ba7ef316777ac5ed
#                                title_and_5_sentences                    2e5d4e7eb4e94e6cb19f314ea0a93575
#                                title_and_first_paragraph                9e257f07d1de424d8eaa433964538849
#                                title_and_first_sentence_each_paragraph  20793956125a498c88209e770a05ac2d
#
#                                                                                                         model_name  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                              ComplementNaiveBayes_SMOTE_v2
#                                title                                                   ComplementNaiveBayes_ROS_v1
#                                title_and_10_sentences                      ComplementNaiveBayes_BorderlineSMOTE_v1
#                                title_and_5_sentences                                 ComplementNaiveBayes_SMOTE_v2
#                                title_and_first_paragraph                             ComplementNaiveBayes_SMOTE_v2
#                                title_and_first_sentence_each_paragraph                 ComplementNaiveBayes_ROS_v1
# Logistic Regression ElasticNet raw_text                                   LogisticRegressionElasticNet_SVMSMOTE_v2
#                                title                                           LogisticRegressionElasticNet_ROS_v1
#                                title_and_10_sentences                        LogisticRegressionElasticNet_SMOTE_v2
#                                title_and_5_sentences                         LogisticRegressionElasticNet_SMOTE_v2
#                                title_and_first_paragraph                            LogisticRegressionElasticNetV1
#                                title_and_first_sentence_each_paragraph    LogisticRegressionElasticNet_SVMSMOTE_v1
# Logistic Regression Lasso      raw_text                                        LogisticRegressionLasso_SVMSMOTE_v1
#                                title                                              LogisticRegressionLasso_SMOTE_v3
#                                title_and_10_sentences                             LogisticRegressionLasso_SMOTE_v1
#                                title_and_5_sentences                    LogisticRegressionLasso_BorderlineSMOTE_v1
#                                title_and_first_paragraph                       LogisticRegressionLasso_SVMSMOTE_v1
#                                title_and_first_sentence_each_paragraph            LogisticRegressionLasso_SMOTE_v3
# Logistic Regression Ridge      raw_text                                    LogisticRegressionRidgeDual_SVMSMOTE_v1
#                                title                                                LogisticRegressionRidge_ROS_v2
#                                title_and_10_sentences                          LogisticRegressionRidge_SVMSMOTE_v2
#                                title_and_5_sentences                           LogisticRegressionRidge_SVMSMOTE_v2
#                                title_and_first_paragraph                                 LogisticRegressionRidgeV1
#                                title_and_first_sentence_each_paragraph         LogisticRegressionRidge_SVMSMOTE_v1
# LogisticRegression             raw_text                                                   LogisticRegression_SMOTE
#                                title                                                   LogisticRegression_SMOTE_v2
#                                title_and_10_sentences                                     LogisticRegression_SMOTE
#                                title_and_5_sentences                                            LogisticRegression
#                                title_and_first_paragraph                               LogisticRegression_SVMSMOTE
#                                title_and_first_sentence_each_paragraph              LogisticRegression_SVMSMOTE_v2
# Naive Bayes                    raw_text                                                        NaiveBayes_SMOTE_v1
#                                title                                                           NaiveBayes_SMOTE_v1
#                                title_and_10_sentences                                            NaiveBayes_ROS_v2
#                                title_and_5_sentences                                           NaiveBayes_SMOTE_v1
#                                title_and_first_paragraph                                         NaiveBayes_ROS_v1
#                                title_and_first_sentence_each_paragraph                         NaiveBayes_SMOTE_v2
# Random Forest                  raw_text                                                        RandomForest_ROS_v2
#                                title                                                         RandomForest_SMOTE_v0
#                                title_and_10_sentences                                          RandomForest_ROS_v2
#                                title_and_5_sentences                                         RandomForest_SMOTE_v1
#                                title_and_first_paragraph                                     RandomForest_SMOTE_v3
#                                title_and_first_sentence_each_paragraph                         RandomForest_ROS_v2
# RidgeClassifier                raw_text                                                RidgeClassifier_SVMSMOTE_v2
#                                title                                                      RidgeClassifier_SMOTE_v2
#                                title_and_10_sentences                                       RidgeClassifier_ROS_v2
#                                title_and_5_sentences                            RidgeClassifier_BorderlineSMOTE_v1
#                                title_and_first_paragraph                                  RidgeClassifier_SMOTE_v3
#                                title_and_first_sentence_each_paragraph                 RidgeClassifier_SVMSMOTE_v1
# SVM                            title                                                    SVM_rbf_BorderlineSMOTE_v3
# XGBoost                        raw_text                                                         XGBoost_narrow_ROS
#                                title                                                            XGBoost_narrow_ROS
#                                title_and_10_sentences                                            XGBoost_broad_ROS
#                                title_and_5_sentences                                            XGBoost_narrow_ROS
#                                title_and_first_paragraph                                        XGBoost_narrow_ROS
#                                title_and_first_sentence_each_paragraph                          XGBoost_narrow_ROS
#
#                                                                                      runName  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                     unruly-panda-298
#                                title                                             fun-pig-957
#                                title_and_10_sentences                         polite-sow-560
#                                title_and_5_sentences                     monumental-bird-839
#                                title_and_first_paragraph                 grandiose-panda-725
#                                title_and_first_sentence_each_paragraph     resilient-fly-950
# Logistic Regression ElasticNet raw_text                                     puzzled-stag-256
#                                title                                      hilarious-bass-662
#                                title_and_10_sentences                        nimble-bear-769
#                                title_and_5_sentences                          spiffy-gnu-327
#                                title_and_first_paragraph                 inquisitive-fly-671
#                                title_and_first_sentence_each_paragraph       lyrical-bug-454
# Logistic Regression Lasso      raw_text                                  agreeable-snail-217
#                                title                                         sassy-goose-241
#                                title_and_10_sentences                       masked-sloth-102
#                                title_and_5_sentences                          suave-tern-801
#                                title_and_first_paragraph                   stylish-snake-385
#                                title_and_first_sentence_each_paragraph    capricious-hog-874
# Logistic Regression Ridge      raw_text                                     caring-steed-396
#                                title                                     nervous-dolphin-268
#                                title_and_10_sentences                         brawny-owl-144
#                                title_and_5_sentences                         languid-rat-658
#                                title_and_first_paragraph                    stylish-croc-902
#                                title_and_first_sentence_each_paragraph     stately-sheep-653
# LogisticRegression             raw_text                                   traveling-frog-777
#                                title                                       mercurial-owl-906
#                                title_and_10_sentences                     enchanting-bug-912
#                                title_and_5_sentences                      traveling-calf-471
#                                title_and_first_paragraph                   redolent-vole-773
#                                title_and_first_sentence_each_paragraph    mercurial-lark-562
# Naive Bayes                    raw_text                                    awesome-goose-912
#                                title                                     persistent-frog-170
#                                title_and_10_sentences                     selective-crab-499
#                                title_and_5_sentences                       skillful-bird-621
#                                title_and_first_paragraph                    powerful-ant-734
#                                title_and_first_sentence_each_paragraph  invincible-robin-569
# Random Forest                  raw_text                                    defiant-stoat-116
#                                title                                      enchanting-fox-844
#                                title_and_10_sentences                      charming-foal-715
#                                title_and_5_sentences                         burly-shrew-250
#                                title_and_first_paragraph                   adaptable-sow-651
#                                title_and_first_sentence_each_paragraph        sedate-ram-157
# RidgeClassifier                raw_text                                  fortunate-robin-766
#                                title                                     selective-squid-637
#                                title_and_10_sentences                       exultant-fish-96
#                                title_and_5_sentences                     thundering-toad-318
#                                title_and_first_paragraph                   worried-zebra-965
#                                title_and_first_sentence_each_paragraph      unruly-stork-889
# SVM                            title                                         gaudy-zebra-507
# XGBoost                        raw_text                                   whimsical-lark-283
#                                title                                       redolent-flea-173
#                                title_and_10_sentences                    victorious-mule-622
#                                title_and_5_sentences                       adaptable-hog-946
#                                title_and_first_paragraph                    dazzling-bass-19
#                                title_and_first_sentence_each_paragraph   respected-steed-214
#
#                                                                                     exp_id  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                 403974574172768364
#                                title                                    782066207554034527
#                                title_and_10_sentences                   259607648085163492
#                                title_and_5_sentences                    337802502687668798
#                                title_and_first_paragraph                144028333125583488
#                                title_and_first_sentence_each_paragraph  953344357930397000
# Logistic Regression ElasticNet raw_text                                 739444040876616155
#                                title                                    670379349728290292
#                                title_and_10_sentences                   561868998222439389
#                                title_and_5_sentences                    413353278508159409
#                                title_and_first_paragraph                825986432523733873
#                                title_and_first_sentence_each_paragraph  608917500105983942
# Logistic Regression Lasso      raw_text                                 714647140246688290
#                                title                                    733586497432226629
#                                title_and_10_sentences                   147390772509322916
#                                title_and_5_sentences                    305842834308422897
#                                title_and_first_paragraph                668172494602539306
#                                title_and_first_sentence_each_paragraph  477346102533341478
# Logistic Regression Ridge      raw_text                                 657608248471841487
#                                title                                    897308797978843317
#                                title_and_10_sentences                   984602950054814583
#                                title_and_5_sentences                    952273200514858211
#                                title_and_first_paragraph                841172181921844184
#                                title_and_first_sentence_each_paragraph  238547463202022078
# LogisticRegression             raw_text                                 192439596583269745
#                                title                                    994490203789117844
#                                title_and_10_sentences                   578109755571984166
#                                title_and_5_sentences                    625496603845001686
#                                title_and_first_paragraph                390228501287553487
#                                title_and_first_sentence_each_paragraph  469929516424148951
# Naive Bayes                    raw_text                                 698515178862981472
#                                title                                    922653119358113438
#                                title_and_10_sentences                   670317052075465740
#                                title_and_5_sentences                    115076748008730427
#                                title_and_first_paragraph                999075269894452490
#                                title_and_first_sentence_each_paragraph  600193128318212811
# Random Forest                  raw_text                                 158464966140657714
#                                title                                    887629779605229965
#                                title_and_10_sentences                   828305168057099788
#                                title_and_5_sentences                    585640748394145749
#                                title_and_first_paragraph                717816920906020463
#                                title_and_first_sentence_each_paragraph  571555803968837483
# RidgeClassifier                raw_text                                 587622999054065488
#                                title                                    251135744092514359
#                                title_and_10_sentences                   413644589270814524
#                                title_and_5_sentences                    472699306880420394
#                                title_and_first_paragraph                698558218872356416
#                                title_and_first_sentence_each_paragraph  540873227915852699
# SVM                            title                                    770844737729863074
# XGBoost                        raw_text                                 378334386819446199
#                                title                                    137439597533805349
#                                title_and_10_sentences                   434872989641341383
#                                title_and_5_sentences                    794337894477119140
#                                title_and_first_paragraph                918923273399675842
#                                title_and_first_sentence_each_paragraph  607917007019840027
#
#                                                                         train_recall_macro_std  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                               0.027166
#                                title                                                  0.027493
#                                title_and_10_sentences                                 0.056189
#                                title_and_5_sentences                                  0.091816
#                                title_and_first_paragraph                              0.042150
#                                title_and_first_sentence_each_paragraph                0.067579
# Logistic Regression ElasticNet raw_text                                               0.021316
#                                title                                                  0.000000
#                                title_and_10_sentences                                 0.024976
#                                title_and_5_sentences                                  0.006283
#                                title_and_first_paragraph                              0.047197
#                                title_and_first_sentence_each_paragraph                0.095428
# Logistic Regression Lasso      raw_text                                               0.081110
#                                title                                                  0.023095
#                                title_and_10_sentences                                 0.008858
#                                title_and_5_sentences                                  0.049447
#                                title_and_first_paragraph                              0.036883
#                                title_and_first_sentence_each_paragraph                0.041786
# Logistic Regression Ridge      raw_text                                               0.037143
#                                title                                                  0.029211
#                                title_and_10_sentences                                 0.012993
#                                title_and_5_sentences                                  0.028401
#                                title_and_first_paragraph                              0.001835
#                                title_and_first_sentence_each_paragraph                0.046256
# LogisticRegression             raw_text                                               0.000000
#                                title                                                  0.010146
#                                title_and_10_sentences                                 0.000000
#                                title_and_5_sentences                                  0.000000
#                                title_and_first_paragraph                              0.069313
#                                title_and_first_sentence_each_paragraph                0.007875
# Naive Bayes                    raw_text                                               0.017642
#                                title                                                  0.037673
#                                title_and_10_sentences                                 0.060844
#                                title_and_5_sentences                                  0.008937
#                                title_and_first_paragraph                              0.020432
#                                title_and_first_sentence_each_paragraph                0.026051
# Random Forest                  raw_text                                               0.044919
#                                title                                                  0.020787
#                                title_and_10_sentences                                 0.060371
#                                title_and_5_sentences                                  0.026364
#                                title_and_first_paragraph                              0.045775
#                                title_and_first_sentence_each_paragraph                0.150867
# RidgeClassifier                raw_text                                               0.036961
#                                title                                                  0.039941
#                                title_and_10_sentences                                 0.064600
#                                title_and_5_sentences                                  0.045340
#                                title_and_first_paragraph                              0.025203
#                                title_and_first_sentence_each_paragraph                0.080349
# SVM                            title                                                  0.064041
# XGBoost                        raw_text                                               0.009383
#                                title                                                  0.011267
#                                title_and_10_sentences                                 0.163878
#                                title_and_5_sentences                                  0.023124
#                                title_and_first_paragraph                              0.003374
#                                title_and_first_sentence_each_paragraph                0.000000
#
#                                                                         train_recall_micro_mean  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                                0.828485
#                                title                                                   0.737889
#                                title_and_10_sentences                                  0.775995
#                                title_and_5_sentences                                   0.663523
#                                title_and_first_paragraph                               0.733376
#                                title_and_first_sentence_each_paragraph                 0.883030
# Logistic Regression ElasticNet raw_text                                                0.779288
#                                title                                                   1.000000
#                                title_and_10_sentences                                  0.702553
#                                title_and_5_sentences                                   0.630134
#                                title_and_first_paragraph                               0.928700
#                                title_and_first_sentence_each_paragraph                 0.799790
# Logistic Regression Lasso      raw_text                                                0.849083
#                                title                                                   0.746215
#                                title_and_10_sentences                                  0.787835
#                                title_and_5_sentences                                   0.610069
#                                title_and_first_paragraph                               0.681315
#                                title_and_first_sentence_each_paragraph                 0.770995
# Logistic Regression Ridge      raw_text                                                0.861612
#                                title                                                   0.948942
#                                title_and_10_sentences                                  0.816630
#                                title_and_5_sentences                                   0.626782
#                                title_and_first_paragraph                               0.970139
#                                title_and_first_sentence_each_paragraph                 0.741094
# LogisticRegression             raw_text                                                1.000000
#                                title                                                   0.715347
#                                title_and_10_sentences                                  1.000000
#                                title_and_5_sentences                                   1.000000
#                                title_and_first_paragraph                               0.692799
#                                title_and_first_sentence_each_paragraph                 0.869914
# Naive Bayes                    raw_text                                                0.838046
#                                title                                                   0.639851
#                                title_and_10_sentences                                  0.686493
#                                title_and_5_sentences                                   0.596030
#                                title_and_first_paragraph                               0.635390
#                                title_and_first_sentence_each_paragraph                 0.829570
# Random Forest                  raw_text                                                0.782643
#                                title                                                   0.486138
#                                title_and_10_sentences                                  0.808406
#                                title_and_5_sentences                                   0.552341
#                                title_and_first_paragraph                               0.583968
#                                title_and_first_sentence_each_paragraph                 0.772801
# RidgeClassifier                raw_text                                                0.670723
#                                title                                                   0.742945
#                                title_and_10_sentences                                  0.734836
#                                title_and_5_sentences                                   0.641634
#                                title_and_first_paragraph                               0.597054
#                                title_and_first_sentence_each_paragraph                 0.742185
# SVM                            title                                                   0.780737
# XGBoost                        raw_text                                                0.992565
#                                title                                                   0.962708
#                                title_and_10_sentences                                  0.905729
#                                title_and_5_sentences                                   0.979758
#                                title_and_first_paragraph                               0.987220
#                                title_and_first_sentence_each_paragraph                 1.000000
#
#                                                                         test_accuracy_mean  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                           0.021009
#                                title                                              0.000000
#                                title_and_10_sentences                             0.010585
#                                title_and_5_sentences                              0.000000
#                                title_and_first_paragraph                          0.000000
#                                title_and_first_sentence_each_paragraph            0.005128
# Logistic Regression ElasticNet raw_text                                           0.042178
#                                title                                              0.010256
#                                title_and_10_sentences                             0.015793
#                                title_and_5_sentences                              0.010585
#                                title_and_first_paragraph                          0.047211
#                                title_and_first_sentence_each_paragraph            0.031178
# Logistic Regression Lasso      raw_text                                           0.026217
#                                title                                              0.005128
#                                title_and_10_sentences                             0.031754
#                                title_and_5_sentences                              0.031594
#                                title_and_first_paragraph                          0.000000
#                                title_and_first_sentence_each_paragraph            0.010505
# Logistic Regression Ridge      raw_text                                           0.015633
#                                title                                              0.000000
#                                title_and_10_sentences                             0.005208
#                                title_and_5_sentences                              0.015633
#                                title_and_first_paragraph                          0.026378
#                                title_and_first_sentence_each_paragraph            0.030929
# LogisticRegression             raw_text                                           0.109574
#                                title                                              0.005128
#                                title_and_10_sentences                             0.026130
#                                title_and_5_sentences                              0.036882
#                                title_and_first_paragraph                          0.005376
#                                title_and_first_sentence_each_paragraph            0.031594
# Naive Bayes                    raw_text                                           0.026385
#                                title                                              0.010585
#                                title_and_10_sentences                             0.026378
#                                title_and_5_sentences                              0.010585
#                                title_and_first_paragraph                          0.000000
#                                title_and_first_sentence_each_paragraph            0.010256
# Random Forest                  raw_text                                           0.021089
#                                title                                              0.010256
#                                title_and_10_sentences                             0.010585
#                                title_and_5_sentences                              0.020761
#                                title_and_first_paragraph                          0.005376
#                                title_and_first_sentence_each_paragraph            0.020921
# RidgeClassifier                raw_text                                           0.047387
#                                title                                              0.005128
#                                title_and_10_sentences                             0.021001
#                                title_and_5_sentences                              0.010753
#                                title_and_first_paragraph                          0.005376
#                                title_and_first_sentence_each_paragraph            0.030929
# SVM                            title                                              0.010585
# XGBoost                        raw_text                                           0.026385
#                                title                                              0.005128
#                                title_and_10_sentences                             0.026466
#                                title_and_5_sentences                              0.010585
#                                title_and_first_paragraph                          0.005208
#                                title_and_first_sentence_each_paragraph            0.015385
#
#                                                                         train_precision_micro_std  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                                  0.020932
#                                title                                                     0.023480
#                                title_and_10_sentences                                    0.057042
#                                title_and_5_sentences                                     0.043877
#                                title_and_first_paragraph                                 0.009499
#                                title_and_first_sentence_each_paragraph                   0.065913
# Logistic Regression ElasticNet raw_text                                                  0.010008
#                                title                                                     0.001469
#                                title_and_10_sentences                                    0.022926
#                                title_and_5_sentences                                     0.026523
#                                title_and_first_paragraph                                 0.014232
#                                title_and_first_sentence_each_paragraph                   0.016321
# Logistic Regression Lasso      raw_text                                                  0.048438
#                                title                                                     0.000256
#                                title_and_10_sentences                                    0.001278
#                                title_and_5_sentences                                     0.026802
#                                title_and_first_paragraph                                 0.034646
#                                title_and_first_sentence_each_paragraph                   0.047051
# Logistic Regression Ridge      raw_text                                                  0.007438
#                                title                                                     0.057143
#                                title_and_10_sentences                                    0.054003
#                                title_and_5_sentences                                     0.026428
#                                title_and_first_paragraph                                 0.047900
#                                title_and_first_sentence_each_paragraph                   0.032328
# LogisticRegression             raw_text                                                  0.000000
#                                title                                                     0.020114
#                                title_and_10_sentences                                    0.000000
#                                title_and_5_sentences                                     0.000000
#                                title_and_first_paragraph                                 0.035813
#                                title_and_first_sentence_each_paragraph                   0.016200
# Naive Bayes                    raw_text                                                  0.024054
#                                title                                                     0.026348
#                                title_and_10_sentences                                    0.039376
#                                title_and_5_sentences                                     0.020656
#                                title_and_first_paragraph                                 0.006465
#                                title_and_first_sentence_each_paragraph                   0.016207
# Random Forest                  raw_text                                                  0.047940
#                                title                                                     0.055223
#                                title_and_10_sentences                                    0.049393
#                                title_and_5_sentences                                     0.028027
#                                title_and_first_paragraph                                 0.043786
#                                title_and_first_sentence_each_paragraph                   0.094057
# RidgeClassifier                raw_text                                                  0.026293
#                                title                                                     0.032220
#                                title_and_10_sentences                                    0.027645
#                                title_and_5_sentences                                     0.006870
#                                title_and_first_paragraph                                 0.032692
#                                title_and_first_sentence_each_paragraph                   0.007762
# SVM                            title                                                     0.070905
# XGBoost                        raw_text                                                  0.192796
#                                title                                                     0.029074
#                                title_and_10_sentences                                    0.166099
#                                title_and_5_sentences                                     0.018138
#                                title_and_first_paragraph                                 0.054059
#                                title_and_first_sentence_each_paragraph                   0.089232
#
#                                                                         test_f1_macro_mean  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                           0.390520
#                                title                                              0.289899
#                                title_and_10_sentences                             0.341736
#                                title_and_5_sentences                              0.324353
#                                title_and_first_paragraph                          0.309241
#                                title_and_first_sentence_each_paragraph            0.356836
# Logistic Regression ElasticNet raw_text                                           0.379513
#                                title                                              0.304981
#                                title_and_10_sentences                             0.345985
#                                title_and_5_sentences                              0.318428
#                                title_and_first_paragraph                          0.333277
#                                title_and_first_sentence_each_paragraph            0.374247
# Logistic Regression Lasso      raw_text                                           0.361870
#                                title                                              0.283887
#                                title_and_10_sentences                             0.332588
#                                title_and_5_sentences                              0.301468
#                                title_and_first_paragraph                          0.322133
#                                title_and_first_sentence_each_paragraph            0.351922
# ...
#
#                                                                         is_count_vectorizer  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# Logistic Regression ElasticNet raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# Logistic Regression Lasso      raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# Logistic Regression Ridge      raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# LogisticRegression             raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# Naive Bayes                    raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# Random Forest                  raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# RidgeClassifier                raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
# SVM                            title                                                  False
# XGBoost                        raw_text                                               False
#                                title                                                  False
#                                title_and_10_sentences                                 False
#                                title_and_5_sentences                                  False
#                                title_and_first_paragraph                              False
#                                title_and_first_sentence_each_paragraph                False
#
#                                                                         n_gram_range_start  \
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# Logistic Regression ElasticNet raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# Logistic Regression Lasso      raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# Logistic Regression Ridge      raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# LogisticRegression             raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# Naive Bayes                    raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# Random Forest                  raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# RidgeClassifier                raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
# SVM                            title                                                     1
# XGBoost                        raw_text                                                  1
#                                title                                                     1
#                                title_and_10_sentences                                    1
#                                title_and_5_sentences                                     1
#                                title_and_first_paragraph                                 1
#                                title_and_first_sentence_each_paragraph                   1
#
#                                                                         n_gram_range_end
# model_type                     unit_of_analysis
# Complement Naive Bayes         raw_text                                                3
#                                title                                                   3
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# Logistic Regression ElasticNet raw_text                                                3
#                                title                                                   1
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               1
#                                title_and_first_sentence_each_paragraph                 3
# Logistic Regression Lasso      raw_text                                                3
#                                title                                                   1
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# Logistic Regression Ridge      raw_text                                                3
#                                title                                                   1
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               1
#                                title_and_first_sentence_each_paragraph                 3
# LogisticRegression             raw_text                                                1
#                                title                                                   1
#                                title_and_10_sentences                                  1
#                                title_and_5_sentences                                   1
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# Naive Bayes                    raw_text                                                3
#                                title                                                   3
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# Random Forest                  raw_text                                                3
#                                title                                                   3
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# RidgeClassifier                raw_text                                                3
#                                title                                                   1
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
# SVM                            title                                                   3
# XGBoost                        raw_text                                                3
#                                title                                                   3
#                                title_and_10_sentences                                  3
#                                title_and_5_sentences                                   3
#                                title_and_first_paragraph                               3
#                                title_and_first_sentence_each_paragraph                 3
#
# [55 rows x 47 columns]

# %% [markdown]
# ### Generate the tables to report

# %%
def display_performance_table(df, metric, display_=True):
    report_table = df.reset_index().copy()
    report_table['result'] = report_table[f'test_{metric}_mean'].map(lambda x: f'{x:.2f}') + \
    ' $\pm$ ' + report_table[f'test_{metric}_std'].map(lambda x: f'{x:.2f}')
    report_table['col_title'] = report_table.unit_of_analysis.str.split('_').str.join(' ') 
    report_table['col_title'] = pd.Categorical(
        report_table.col_title,
        categories=['title', 'title and first paragraph', 'title and 5 sentences', 'title and 10 sentences',
                    'title and first sentence each paragraph', 'raw text'],
        ordered=True)
    report_table = report_table[['model_type', 'col_title', 'result']]\
        .pivot_table(index='model_type', columns=['col_title'], values=['result'], aggfunc='first', fill_value=0)\
        .droplevel(0, axis=1)

    report_table.columns.names = [None]

    # Highlight best scoring models according to their average
    mean_perf_arr = report_table.applymap(lambda x: float(str(x).split(' ')[0])).to_numpy()
    highlight_mask = mean_perf_arr == mean_perf_arr.max()
    report_table_arr = report_table.to_numpy()  # Note it passes the array by reference
    report_table_arr[highlight_mask] = '**' + report_table_arr[highlight_mask] + '**'

    if display_:
        display(Markdown(report_table.to_markdown()))
    else:
        return report_table.to_markdown()

# %%
display_performance_table(df=best_models_df, metric='f1_micro', display_=True)
# Out:
# | model_type                     | title           | title and first paragraph   | title and 5 sentences   | title and 10 sentences   | title and first sentence each paragraph   | raw text            |
# |:-------------------------------|:----------------|:----------------------------|:------------------------|:-------------------------|:------------------------------------------|:--------------------|
# | Complement Naive Bayes         | 0.35 $\pm$ 0.01 | 0.37 $\pm$ 0.00             | 0.39 $\pm$ 0.03         | 0.41 $\pm$ 0.02          | 0.42 $\pm$ 0.01                           | 0.45 $\pm$ 0.01     |
# | Logistic Regression ElasticNet | 0.35 $\pm$ 0.02 | 0.39 $\pm$ 0.03             | 0.38 $\pm$ 0.02         | 0.41 $\pm$ 0.02          | 0.43 $\pm$ 0.02                           | 0.43 $\pm$ 0.01     |
# | Logistic Regression Lasso      | 0.34 $\pm$ 0.02 | 0.39 $\pm$ 0.02             | 0.36 $\pm$ 0.03         | 0.39 $\pm$ 0.00          | 0.40 $\pm$ 0.01                           | 0.42 $\pm$ 0.02     |
# | Logistic Regression Ridge      | 0.37 $\pm$ 0.01 | 0.42 $\pm$ 0.01             | 0.38 $\pm$ 0.03         | 0.41 $\pm$ 0.01          | 0.44 $\pm$ 0.01                           | **0.46 $\pm$ 0.03** |
# | LogisticRegression             | 0.34 $\pm$ 0.03 | 0.38 $\pm$ 0.01             | 0.40 $\pm$ 0.02         | 0.40 $\pm$ 0.03          | 0.40 $\pm$ 0.02                           | 0.43 $\pm$ 0.02     |
# | Naive Bayes                    | 0.33 $\pm$ 0.01 | 0.36 $\pm$ 0.02             | 0.39 $\pm$ 0.03         | 0.41 $\pm$ 0.02          | 0.43 $\pm$ 0.03                           | **0.46 $\pm$ 0.03** |
# | Random Forest                  | 0.28 $\pm$ 0.03 | 0.31 $\pm$ 0.02             | 0.35 $\pm$ 0.03         | 0.38 $\pm$ 0.02          | 0.36 $\pm$ 0.02                           | 0.43 $\pm$ 0.03     |
# | RidgeClassifier                | 0.36 $\pm$ 0.03 | 0.40 $\pm$ 0.02             | 0.39 $\pm$ 0.01         | 0.41 $\pm$ 0.01          | 0.43 $\pm$ 0.03                           | 0.45 $\pm$ 0.02     |
# | SVM                            | 0.35 $\pm$ 0.02 | 0                           | 0                       | 0                        | 0                                         | 0                   |
# | XGBoost                        | 0.36 $\pm$ 0.01 | 0.37 $\pm$ 0.01             | 0.37 $\pm$ 0.01         | 0.38 $\pm$ 0.00          | 0.39 $\pm$ 0.02                           | 0.44 $\pm$ 0.02     |

# %%
display_performance_table(df=best_models_df, metric='precision_micro', display_=True)
# Out:
# | model_type                     | title           | title and first paragraph   | title and 5 sentences   | title and 10 sentences   | title and first sentence each paragraph   | raw text            |
# |:-------------------------------|:----------------|:----------------------------|:------------------------|:-------------------------|:------------------------------------------|:--------------------|
# | Complement Naive Bayes         | 0.28 $\pm$ 0.01 | 0.30 $\pm$ 0.01             | 0.32 $\pm$ 0.04         | 0.32 $\pm$ 0.03          | 0.32 $\pm$ 0.03                           | 0.38 $\pm$ 0.02     |
# | Logistic Regression ElasticNet | 0.31 $\pm$ 0.02 | 0.43 $\pm$ 0.03             | 0.34 $\pm$ 0.02         | 0.38 $\pm$ 0.01          | 0.42 $\pm$ 0.05                           | 0.42 $\pm$ 0.02     |
# | Logistic Regression Lasso      | 0.27 $\pm$ 0.02 | 0.35 $\pm$ 0.01             | 0.32 $\pm$ 0.04         | 0.36 $\pm$ 0.03          | 0.37 $\pm$ 0.02                           | 0.39 $\pm$ 0.02     |
# | Logistic Regression Ridge      | 0.30 $\pm$ 0.00 | 0.34 $\pm$ 0.02             | 0.35 $\pm$ 0.03         | 0.34 $\pm$ 0.04          | 0.42 $\pm$ 0.02                           | 0.36 $\pm$ 0.03     |
# | LogisticRegression             | 0.27 $\pm$ 0.02 | 0.33 $\pm$ 0.02             | 0.40 $\pm$ 0.01         | 0.40 $\pm$ 0.04          | 0.37 $\pm$ 0.02                           | **0.51 $\pm$ 0.03** |
# | Naive Bayes                    | 0.29 $\pm$ 0.01 | 0.32 $\pm$ 0.02             | 0.36 $\pm$ 0.03         | 0.38 $\pm$ 0.03          | 0.36 $\pm$ 0.02                           | 0.38 $\pm$ 0.04     |
# | Random Forest                  | 0.28 $\pm$ 0.04 | 0.32 $\pm$ 0.06             | 0.35 $\pm$ 0.01         | 0.32 $\pm$ 0.02          | 0.35 $\pm$ 0.02                           | 0.39 $\pm$ 0.03     |
# | RidgeClassifier                | 0.31 $\pm$ 0.02 | 0.36 $\pm$ 0.01             | 0.34 $\pm$ 0.01         | 0.37 $\pm$ 0.02          | 0.45 $\pm$ 0.04                           | 0.48 $\pm$ 0.04     |
# | SVM                            | 0.28 $\pm$ 0.00 | 0                           | 0                       | 0                        | 0                                         | 0                   |
# | XGBoost                        | 0.25 $\pm$ 0.01 | 0.26 $\pm$ 0.01             | 0.26 $\pm$ 0.01         | 0.30 $\pm$ 0.02          | 0.31 $\pm$ 0.02                           | 0.36 $\pm$ 0.04     |

# %%
display_performance_table(df=best_models_df, metric='recall_micro', display_=True)
# Out:
# | model_type                     | title           | title and first paragraph   | title and 5 sentences   | title and 10 sentences   | title and first sentence each paragraph   | raw text        |
# |:-------------------------------|:----------------|:----------------------------|:------------------------|:-------------------------|:------------------------------------------|:----------------|
# | Complement Naive Bayes         | 0.54 $\pm$ 0.01 | 0.63 $\pm$ 0.07             | 0.53 $\pm$ 0.06         | 0.63 $\pm$ 0.09          | 0.65 $\pm$ 0.07                           | 0.61 $\pm$ 0.02 |
# | Logistic Regression ElasticNet | 0.40 $\pm$ 0.06 | 0.39 $\pm$ 0.03             | 0.48 $\pm$ 0.02         | 0.49 $\pm$ 0.06          | 0.47 $\pm$ 0.02                           | 0.47 $\pm$ 0.04 |
# | Logistic Regression Lasso      | 0.55 $\pm$ 0.04 | 0.52 $\pm$ 0.04             | 0.47 $\pm$ 0.04         | 0.46 $\pm$ 0.04          | 0.48 $\pm$ 0.02                           | 0.48 $\pm$ 0.02 |
# | Logistic Regression Ridge      | 0.53 $\pm$ 0.04 | 0.61 $\pm$ 0.08             | 0.47 $\pm$ 0.05         | 0.57 $\pm$ 0.07          | 0.52 $\pm$ 0.05                           | 0.68 $\pm$ 0.04 |
# | LogisticRegression             | 0.53 $\pm$ 0.07 | 0.52 $\pm$ 0.07             | 0.41 $\pm$ 0.04         | 0.43 $\pm$ 0.02          | 0.44 $\pm$ 0.02                           | 0.39 $\pm$ 0.02 |
# | Naive Bayes                    | 0.44 $\pm$ 0.04 | 0.50 $\pm$ 0.06             | 0.47 $\pm$ 0.06         | 0.48 $\pm$ 0.04          | 0.56 $\pm$ 0.05                           | 0.63 $\pm$ 0.03 |
# | Random Forest                  | 0.36 $\pm$ 0.08 | 0.46 $\pm$ 0.09             | 0.41 $\pm$ 0.02         | 0.51 $\pm$ 0.04          | 0.40 $\pm$ 0.04                           | 0.51 $\pm$ 0.03 |
# | RidgeClassifier                | 0.46 $\pm$ 0.07 | 0.54 $\pm$ 0.05             | 0.51 $\pm$ 0.05         | 0.49 $\pm$ 0.02          | 0.46 $\pm$ 0.04                           | 0.45 $\pm$ 0.04 |
# | SVM                            | 0.56 $\pm$ 0.11 | 0                           | 0                       | 0                        | 0                                         | 0               |
# | XGBoost                        | 0.68 $\pm$ 0.05 | **0.71 $\pm$ 0.03**         | 0.66 $\pm$ 0.01         | 0.59 $\pm$ 0.07          | 0.55 $\pm$ 0.06                           | 0.63 $\pm$ 0.09 |

# %%
display_performance_table(df=best_models_df, metric='accuracy', display_=True)
# Out:
# | model_type                     | title           | title and first paragraph   | title and 5 sentences   | title and 10 sentences   | title and first sentence each paragraph   | raw text            |
# |:-------------------------------|:----------------|:----------------------------|:------------------------|:-------------------------|:------------------------------------------|:--------------------|
# | Complement Naive Bayes         | 0.00 $\pm$ 0.00 | 0.00 $\pm$ 0.00             | 0.00 $\pm$ 0.00         | 0.01 $\pm$ 0.01          | 0.01 $\pm$ 0.01                           | 0.02 $\pm$ 0.01     |
# | Logistic Regression ElasticNet | 0.01 $\pm$ 0.01 | 0.05 $\pm$ 0.05             | 0.01 $\pm$ 0.01         | 0.02 $\pm$ 0.01          | 0.03 $\pm$ 0.01                           | 0.04 $\pm$ 0.02     |
# | Logistic Regression Lasso      | 0.01 $\pm$ 0.01 | 0.00 $\pm$ 0.00             | 0.03 $\pm$ 0.01         | 0.03 $\pm$ 0.02          | 0.01 $\pm$ 0.01                           | 0.03 $\pm$ 0.01     |
# | Logistic Regression Ridge      | 0.00 $\pm$ 0.00 | 0.03 $\pm$ 0.02             | 0.02 $\pm$ 0.01         | 0.01 $\pm$ 0.01          | 0.03 $\pm$ 0.03                           | 0.02 $\pm$ 0.01     |
# | LogisticRegression             | 0.01 $\pm$ 0.01 | 0.01 $\pm$ 0.01             | 0.04 $\pm$ 0.02         | 0.03 $\pm$ 0.01          | 0.03 $\pm$ 0.01                           | **0.11 $\pm$ 0.02** |
# | Naive Bayes                    | 0.01 $\pm$ 0.01 | 0.00 $\pm$ 0.00             | 0.01 $\pm$ 0.01         | 0.03 $\pm$ 0.02          | 0.01 $\pm$ 0.01                           | 0.03 $\pm$ 0.02     |
# | Random Forest                  | 0.01 $\pm$ 0.01 | 0.01 $\pm$ 0.01             | 0.02 $\pm$ 0.02         | 0.01 $\pm$ 0.01          | 0.02 $\pm$ 0.01                           | 0.02 $\pm$ 0.01     |
# | RidgeClassifier                | 0.01 $\pm$ 0.01 | 0.01 $\pm$ 0.01             | 0.01 $\pm$ 0.02         | 0.02 $\pm$ 0.02          | 0.03 $\pm$ 0.03                           | 0.05 $\pm$ 0.01     |
# | SVM                            | 0.01 $\pm$ 0.01 | 0                           | 0                       | 0                        | 0                                         | 0                   |
# | XGBoost                        | 0.01 $\pm$ 0.01 | 0.01 $\pm$ 0.01             | 0.01 $\pm$ 0.01         | 0.03 $\pm$ 0.02          | 0.02 $\pm$ 0.02                           | 0.03 $\pm$ 0.02     |

# %% [markdown]
# ## Retrieve the best experiments runs and write them in a single experiment

# %%
os.make_dir('post_processed_runs', exists_ok=True)
os.chdir('post_processed_runs')
client =  MlflowClient()

# %%
for unit_of_analysis, df in best_models_df.reset_index().groupby(['unit_of_analysis']):
    print(f"best_performing_models_{unit_of_analysis}")
    new_exp_id = client.create_experiment(f"best_performing_models_{unit_of_analysis}")
    
    try:
        # Add run information to the experiment
        for idx, row in df.iterrows():
            with mlflow.start_run(experiment_id=new_exp_id):
                for col in df.columns:
                    if 'train'in col or 'test' in col: 
                        log_metric(col, row[col])

                    else:
                        log_param(col, row[col])

            mlflow.end_run()
    except Exception as e:
        print(e)
        pass
# Out:
# best_performing_models_raw_text
# best_performing_models_title
# best_performing_models_title_and_10_sentences
# best_performing_models_title_and_5_sentences
# best_performing_models_title_and_first_paragraph
# best_performing_models_title_and_first_sentence_each_paragraph

# %% [markdown]
# # Outer CV Metrics

# %% [markdown]
# Retrieve all outer CV Metrics, (subset the top performing ones), and write them to new experiments where they are well grouped per unit of analysis and model type

# %%
analysis_level = 'outer_cv'
query = f"params.analysis_level = '{analysis_level}'"

rows = []
for exp_i, exp_id in enumerate(exp_ids):
    # Retrieve 'model_wide' runs of the experiment
    try:
        runs = client.search_runs(experiment_ids=exp_id, filter_string=query)
    except:
        print(f'problems with exp_id: {exp_id} in position {exp_i}')
        continue
        
    # Add relevant parameters to the row
    for run in runs:
        row_dict = {'exp_id': exp_id, 'run_uuid': run.info.run_uuid, 'runName': run.data.tags['mlflow.runName'],
                    **run.data.metrics, **run.data.params}
        rows.append(row_dict)
        
    if exp_i % 100 == 0 and exp_i!=0:
        pd.DataFrame(rows).set_index(['run_uuid', 'model_name', 'runName']).sort_index().to_csv('all_outer_cv_results.csv')
    
pd.DataFrame(rows).set_index(['run_uuid', 'model_name', 'runName']).sort_index().to_csv('all_outer_cv_results.csv')
# Out:
# problems with exp_id: 168812780760165522 in position 1942

# %%
ocv_df = pd.read_csv('all_outer_cv_results.csv', index_col=['exp_id','run_uuid', 'model_name', 'runName'])

# %%
ocv_df['model_type'] = ocv_df.index.get_level_values(2).map(recode_dict)

# %%
ocv_df.model_type.value_counts()
# Out:
# Logistic Regression Ridge         3982
# Logistic Regression ElasticNet    2333
# RidgeClassifier                   2093
# LogisticRegression                1857
# Logistic Regression Lasso         1608
# Random Forest                      540
# Naive Bayes                        324
# Complement Naive Bayes             252
# XGBoost                            166
# SVM                                111
# Name: model_type, dtype: int64

# %% [markdown]
# ## Post process results of experiments

# %%
os.make_dir('post_processed_runs', exists_ok=True)
os.chdir('post_processed_runs')
client =  MlflowClient()

# %% [markdown]
# ### Create one experiment per model type

# %%
for model_type, df in ocv_df.reset_index().groupby(['model_type']):
    new_exp_name = f"all_runs_of_{model_type}"
    print(new_exp_name)
    new_exp_id = client.create_experiment(new_exp_name)
    
    try:
        # Add run information to the experiment
        for idx, row in df.iterrows():
            with mlflow.start_run(experiment_id=new_exp_id):
                for col in df.columns:
                    if 'train'in col or 'test' in col: 
                        log_metric(col, row[col])

                    else:
                        log_param(col, row[col])

            mlflow.end_run()
    except Exception as e:
        print(e)
        pass
# Out:
# all_runs_of_Complement Naive Bayes

# %% [markdown]
# ### Create one experiment per unit of analysis

# %%
for unit_of_analysis, df in ocv_df.reset_index().groupby(['unit_of_analysis']):
    new_exp_name = f"all_runs_of_{unit_of_analysis}"
    print(new_exp_name)
    new_exp_id = client.create_experiment(new_exp_name)
    
    try:
        # Add run information to the experiment
        for idx, row in df.iterrows():
            with mlflow.start_run(experiment_id=new_exp_id):
                for col in df.columns:
                    if 'train'in col or 'test' in col: 
                        log_metric(col, row[col])

                    else:
                        log_param(col, row[col])

            mlflow.end_run()
    except Exception as e:
        print(e)
        pass

# %% [markdown]
# ### Create one experiment per model type per unit of analysis

# %%
for (model_type, unit_of_analysis), df in ocv_df.reset_index().groupby(['model_type','unit_of_analysis']):
    new_exp_name = f"all_runs_of_{model_type}_{unit_of_analysis}"
    print(new_exp_name)
    new_exp_id = client.create_experiment(new_exp_name)
    
    try:
        # Add run information to the experiment
        for idx, row in df.iterrows():
            with mlflow.start_run(experiment_id=new_exp_id):
                for col in df.columns:
                    if 'train'in col or 'test' in col: 
                        log_metric(col, row[col])

                    else:
                        log_param(col, row[col])

            mlflow.end_run()
    except Exception as e:
        print(e)
        pass

# %% [markdown]
# # Extra stuff

# %%
test_id = run_ids[1]
test_query = "params.analysis_level = '{analysis_level}'"

# %%
runs = client.search_runs(
    experiment_ids=[test_id],
    filter_string=test_query.format(analysis_level=analysis_level))

# %%
len(runs)

# %%
runs[0].data.metrics
# Out:
# {'train_recall_macro': 0.717208310100105,
#  'train_accuracy': 0.17054263565891473,
#  'train_f1_macro': 0.5289355975824069,
#  'test_f1_macro': 0.2727723308052808,
#  'test_precision_macro': 0.24911713731277244,
#  'train_precision_micro': 0.49831346568861945,
#  'train_precision_macro': 0.44566856489109563,
#  'test_precision_micro': 0.3358132789723725,
#  'test_accuracy': 0.03225806451612903,
#  'test_recall_macro': 0.34139809415202177,
#  'train_recall_micro': 0.7371794871794872,
#  'train_f1_micro': 0.5736494831238187,
#  'test_recall_micro': 0.4267515923566879,
#  'test_f1_micro': 0.3623497081652117}

# %%
runs[0].data.params
# Out:
# {'min_df': '0.0001',
#  'multilabel_type': 'chain',
#  'base_estimator_name': "Pipeline(steps=[('up', BorderlineSMOTE()),\n                ('preproc', StandardScaler(with_mean=False)),\n                ('model', RidgeClassifier(max_iter=100000))])",
#  'model_name': 'RidgeClassifier_BorderlineSMOTE_v2',
#  'k_neighbors': '2',
#  'kind': 'borderline-2',
#  'min_var': '0.001',
#  'sampling_strategy': 'not majority',
#  'n_features': '37',
#  'tfidf': 'True',
#  'class_weight': 'balanced',
#  'language': 'ru',
#  'corr_threshold': '0.9',
#  'analysis_level': 'outer_cv',
#  'spacy_model_used': 'ru_core_news_sm',
#  'max_df': '0.4',
#  'with_std': 'True',
#  'vectorizer_max_features': '10000',
#  'is_count_vectorizer': 'False',
#  'alpha': '301.93720962923425',
#  'unit_of_analysis': 'title_and_10_sentences',
#  'n_gram_range_start': '1',
#  'm_neighbors': '7',
#  'n_gram_range_end': '3'}

# %%
runs = client.search_runs(
    experiment_ids='656382851946062557', 
    filter_string=test_query.format(analysis_level='outer_cv'),
    run_view_type=ViewType.ALL)

# %%
runs[0].info
# Out:
# <RunInfo: artifact_uri='/scratch/jberme/tune_russian/mlruns/656382851946062557/9847672f5c574ca6ae4963c15a7851a5/artifacts', end_time=1674322806703, experiment_id='656382851946062557', lifecycle_stage='active', run_id='9847672f5c574ca6ae4963c15a7851a5', run_uuid='9847672f5c574ca6ae4963c15a7851a5', start_time=1674322805914, status='FINISHED', user_id='jberme'>

# %%
runs[0].data.tags
# Out:
# {'mlflow.source.name': 'benchmark_subtask_2.py',
#  'mlflow.user': 'jberme',
#  'mlflow.runName': 'honorable-wolf-618',
#  'mlflow.source.git.commit': '3dc0c6739468e9b07b8dd09a5611b105d391ef5a',
#  'mlflow.source.type': 'LOCAL'}

# %%
runs[0].info.run_uuid
# Out:
# '9847672f5c574ca6ae4963c15a7851a5'

# %%
runs[0]
# Out:
# <Run: data=<RunData: metrics={'test_accuracy': 0.03225806451612903,
#  'test_f1_macro': 0.2727723308052808,
#  'test_f1_micro': 0.3623497081652117,
#  'test_precision_macro': 0.24911713731277244,
#  'test_precision_micro': 0.3358132789723725,
#  'test_recall_macro': 0.34139809415202177,
#  'test_recall_micro': 0.4267515923566879,
#  'train_accuracy': 0.17054263565891473,
#  'train_f1_macro': 0.5289355975824069,
#  'train_f1_micro': 0.5736494831238187,
#  'train_precision_macro': 0.44566856489109563,
#  'train_precision_micro': 0.49831346568861945,
#  'train_recall_macro': 0.717208310100105,
#  'train_recall_micro': 0.7371794871794872}, params={'alpha': '301.93720962923425',
#  'analysis_level': 'outer_cv',
#  'base_estimator_name': "Pipeline(steps=[('up', BorderlineSMOTE()),\n"
#                         "                ('preproc', "
#                         'StandardScaler(with_mean=False)),\n'
#                         "                ('model', "
#                         'RidgeClassifier(max_iter=100000))])',
#  'class_weight': 'balanced',
#  'corr_threshold': '0.9',
#  'is_count_vectorizer': 'False',
#  'k_neighbors': '2',
#  'kind': 'borderline-2',
#  'language': 'ru',
#  'm_neighbors': '7',
#  'max_df': '0.4',
#  'min_df': '0.0001',
#  'min_var': '0.001',
#  'model_name': 'RidgeClassifier_BorderlineSMOTE_v2',
#  'multilabel_type': 'chain',
#  'n_features': '37',
#  'n_gram_range_end': '3',
#  'n_gram_range_start': '1',
#  'sampling_strategy': 'not majority',
#  'spacy_model_used': 'ru_core_news_sm',
#  'tfidf': 'True',
#  'unit_of_analysis': 'title_and_10_sentences',
#  'vectorizer_max_features': '10000',
#  'with_std': 'True'}, tags={'mlflow.runName': 'honorable-wolf-618',
#  'mlflow.source.git.commit': '3dc0c6739468e9b07b8dd09a5611b105d391ef5a',
#  'mlflow.source.name': 'benchmark_subtask_2.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'jberme'}>, info=<RunInfo: artifact_uri='/scratch/jberme/tune_russian/mlruns/656382851946062557/9847672f5c574ca6ae4963c15a7851a5/artifacts', end_time=1674322806703, experiment_id='656382851946062557', lifecycle_stage='active', run_id='9847672f5c574ca6ae4963c15a7851a5', run_uuid='9847672f5c574ca6ae4963c15a7851a5', start_time=1674322805914, status='FINISHED', user_id='jberme'>>

# %%
all_experiments = [exp.experiment_id for exp in mlflow.search_experiments()]

# %%
all_experiments
