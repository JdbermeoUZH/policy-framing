# %%
import os
from typing import List

import pandas as pd
import spacy
from scipy.stats import loguniform
from sklearn.metrics import f1_score
from sklearn.model_selection import RandomizedSearchCV, cross_validate
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multioutput import MultiOutputClassifier

from preprocessing.InputDataset import FramingArticleDataset
from preprocessing.BOWPipeline import BOWPipeline, basic_tokenizing_and_cleaning

DATA_DIR = os.path.join('..', 'data')

# %% [markdown]
# ## Load the Data

# %%
en_train = FramingArticleDataset(data_dir=DATA_DIR, language='en', subtask=2, split='train',
                                 load_preprocessed_units_of_analysis=True, units_of_analysis_dir= os.path.join(DATA_DIR, 'preprocessed'))
# Out:
# 433it [00:00, 20058.24it/s]

# %% [markdown]
# ## Binarize the labels

# %%
labels = ('fairness_and_equality', 'security_and_defense', 'crime_and_punishment', 'morality', 'policy_prescription_and_evaluation',
          'capacity_and_resources', 'economic', 'cultural_identity', 'health_and_safety', 'quality_of_life', 'legality_constitutionality_and_jurisprudence',
          'political', 'public_opinion', 'external_regulation_and_reputation')

# %%
mlb = MultiLabelBinarizer()
mlb.fit([labels])
# Out:
# MultiLabelBinarizer()

# %%
mlb.classes_
# Out:
# array(['capacity_and_resources', 'crime_and_punishment',
#        'cultural_identity', 'economic',
#        'external_regulation_and_reputation', 'fairness_and_equality',
#        'health_and_safety',
#        'legality_constitutionality_and_jurisprudence', 'morality',
#        'policy_prescription_and_evaluation', 'political',
#        'public_opinion', 'quality_of_life', 'security_and_defense'],
#       dtype=object)

# %%
y_train = mlb.transform(en_train.df.frames.str.lower().str.split(','))

# %% [markdown]
# ## Vectorize the documents

# %%
en_nlp = spacy.load('en_core_web_sm')

# %%
vectorizing_pipeline = BOWPipeline(
        tokenizer=lambda string: basic_tokenizing_and_cleaning(string, spacy_nlp_model=en_nlp),
        use_tfidf=True,
        min_df=0.05,
        max_df=0.95,
        ngram_range=(1, 1),
        max_features=1000
    )

vectorizing_pipeline.add_low_var_threshold(min_var=1e-3)
vectorizing_pipeline.add_corr_filter(corr_threshold=0.9)

# %%
X_train = vectorizing_pipeline.pipeline.fit_transform(en_train.df.title_and_first_paragraph)

# %% [markdown]
# ## Test training multi-output classifier

# %%
clfs = {'svm': SVC(), 'linear_svm': LinearSVC(), 'log_reg': LogisticRegression(), 'ridge': RidgeClassifier(),
        'rf': RandomForestClassifier, 'xgboost': XGBClassifier(), 'xgboostRF': XGBRFClassifier()}

# %% [markdown]
# ### Independent multilabel

# %% [markdown]
# #### Nested cross validation

# %%
# Params of fitting
param_combinations = 10
search_loop_cv = 2
scoring_function = 'f1_micro', 'f1_macro', 'accuracy', 'precision_micro', 'precision_macro', 'recall_micro', 'recall_macro'
model_selection_loop_cv = 10

# %%
# Wrap as a multilabel classifier
mlo_clf = MultiOutputClassifier(clfs['svm'], n_jobs=2)

# Define search space of the model
params = {
    'estimator__C': loguniform(1e-2, 1e3),
    'estimator__gamma': loguniform(1e-4, 1e-1)
}

# Define inner loop search
search_routine = RandomizedSearchCV(
    estimator=mlo_clf,
    param_distributions=params,
    n_iter=param_combinations,
    cv=search_loop_cv,
    scoring=scoring_function,
    refit='f1_micro'
)

# Define Outer-loop routine and execute it
model_performance = cross_validate(
    search_routine,
    X_train,
    y_train,
    scoring=scoring_function,
    cv=model_selection_loop_cv,
    return_estimator=True
)
# Out:
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1592: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1592: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/juanbermeo/anaconda3/envs/Framing/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model_performance
# Out:
# {'fit_time': array([0.98427534, 0.96864033, 1.04488873, 1.00687385, 1.05006814,
#         1.04519653, 1.06866026, 1.06120825, 1.00300288, 1.01657963]),
#  'score_time': array([0.02020073, 0.01956248, 0.01957321, 0.01884341, 0.02410173,
#         0.01908326, 0.02055025, 0.02115512, 0.02114248, 0.01933861]),
#  'estimator': [RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f241c19da00>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f241e2d2bb0>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f24057b2820>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f241c1a04f0>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f240581f0d0>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f241ec5b520>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2407d31700>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f241c149460>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f24079b6f40>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2407e10f40>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405861850>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405976a90>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405976dc0>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405746910>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f240575ac10>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405839b20>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f24058b87c0>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f24058391c0>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro')),
#   RandomizedSearchCV(cv=2,
#                      estimator=MultiOutputClassifier(estimator=SVC(), n_jobs=2),
#                      param_distributions={'estimator__C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f240576e670>,
#                                           'estimator__gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f2405839a00>},
#                      refit='f1_micro',
#                      scoring=('f1_micro', 'f1_macro', 'accuracy',
#                               'precision_micro', 'precision_macro',
#                               'recall_micro', 'recall_macro'))],
#  'test_f1_micro': array([0.5087108 , 0.4751773 , 0.50331126, 0.52777778, 0.6259542 ,
#         0.5093633 , 0.55972696, 0.54471545, 0.52918288, 0.5734767 ]),
#  'test_f1_macro': array([0.29722086, 0.29289651, 0.33938493, 0.32898237, 0.33278128,
#         0.32459393, 0.36734428, 0.29508967, 0.30409488, 0.27848634]),
#  'test_accuracy': array([0.04545455, 0.02325581, 0.04651163, 0.        , 0.06976744,
#         0.02325581, 0.02325581, 0.06976744, 0.04651163, 0.04651163]),
#  'test_precision_micro': array([0.8021978 , 0.60909091, 0.57575758, 0.61290323, 0.70689655,
#         0.70833333, 0.78095238, 0.54032258, 0.5483871 , 0.59259259]),
#  'test_precision_macro': array([0.48941683, 0.40664761, 0.42439019, 0.4350565 , 0.37678571,
#         0.4616853 , 0.48300271, 0.30876546, 0.37217461, 0.28932137]),
#  'test_recall_micro': array([0.37244898, 0.38953488, 0.44705882, 0.46341463, 0.56164384,
#         0.39766082, 0.43617021, 0.54918033, 0.5112782 , 0.55555556]),
#  'test_recall_macro': array([0.23906076, 0.26664168, 0.31252369, 0.29818488, 0.32471685,
#         0.27568634, 0.32508753, 0.33127983, 0.30186064, 0.27968086])}

# %%
model_performance['test_f1_micro'].mean()
# Out:
# 0.5376282602091063

# %%
model_performance['test_f1_micro'].std()
# Out:
# 0.030491075625106688

# %%
pd.DataFrame(model_performance['estimator'][0].cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.024796      0.000499         0.026907        0.001548
# 1       0.022196      0.000960         0.023957        0.001274
# 2       0.019843      0.000333         0.024559        0.001668
# 3       0.023337      0.000921         0.029217        0.002111
# 4       0.022016      0.000064         0.027822        0.002454
# 5       0.019391      0.000604         0.023609        0.000736
# 6       0.017673      0.000115         0.022433        0.000376
# 7       0.020107      0.001608         0.025043        0.001235
# 8       0.017614      0.000649         0.024648        0.000934
# 9       0.018714      0.001204         0.025016        0.001513
#
#   param_estimator__C param_estimator__gamma  \
# 0           0.226226               0.041095
# 1         730.080254               0.000381
# 2           0.225737               0.006832
# 3           8.631638               0.022478
# 4           2.995993               0.026783
# 5           0.216176               0.003754
# 6           0.308084               0.000688
# 7           0.074103               0.000896
# 8           0.010271               0.007508
# 9            1.56193               0.000564
#
#                                               params  split0_test_f1_micro  \
# 0  {'estimator__C': 0.22622573283031963, 'estimat...              0.359610
# 1  {'estimator__C': 730.0802536296363, 'estimator...              0.441968
# 2  {'estimator__C': 0.22573658804182628, 'estimat...              0.359610
# 3  {'estimator__C': 8.631637502243715, 'estimator...              0.421965
# 4  {'estimator__C': 2.995992829648104, 'estimator...              0.368526
# 5  {'estimator__C': 0.2161763105544836, 'estimato...              0.359610
# 6  {'estimator__C': 0.3080838358481395, 'estimato...              0.359610
# 7  {'estimator__C': 0.07410334600553543, 'estimat...              0.359610
# 8  {'estimator__C': 0.010270589297712174, 'estima...              0.359610
# 9  {'estimator__C': 1.5619304706549475, 'estimato...              0.359610
#
#    split1_test_f1_micro  mean_test_f1_micro  ...  split0_test_recall_micro  \
# 0              0.445513            0.402562  ...                  0.273954
# 1              0.521589            0.481779  ...                  0.321188
# 2              0.445513            0.402562  ...                  0.273954
# 3              0.512642            0.467303  ...                  0.295547
# 4              0.508099            0.438312  ...                  0.249663
# 5              0.445513            0.402562  ...                  0.273954
# 6              0.445513            0.402562  ...                  0.273954
# 7              0.445513            0.402562  ...                  0.273954
# 8              0.445513            0.402562  ...                  0.273954
# 9              0.445513            0.402562  ...                  0.273954
#
#    split1_test_recall_micro  mean_test_recall_micro  std_test_recall_micro  \
# 0                  0.415546                0.344750               0.070796
# 1                  0.451420                0.386304               0.065116
# 2                  0.415546                0.344750               0.070796
# 3                  0.439462                0.367504               0.071958
# 4                  0.445441                0.347552               0.097889
# 5                  0.415546                0.344750               0.070796
# 6                  0.415546                0.344750               0.070796
# 7                  0.415546                0.344750               0.070796
# 8                  0.415546                0.344750               0.070796
# 9                  0.415546                0.344750               0.070796
#
#    rank_test_recall_micro  split0_test_recall_macro  split1_test_recall_macro  \
# 0                       4                  0.142857                  0.214286
# 1                       1                  0.183038                  0.252862
# 2                       4                  0.142857                  0.214286
# 3                       2                  0.167477                  0.240315
# 4                       3                  0.137677                  0.241263
# 5                       4                  0.142857                  0.214286
# 6                       4                  0.142857                  0.214286
# 7                       4                  0.142857                  0.214286
# 8                       4                  0.142857                  0.214286
# 9                       4                  0.142857                  0.214286
#
#    mean_test_recall_macro  std_test_recall_macro  rank_test_recall_macro
# 0                0.178571               0.035714                       4
# 1                0.217950               0.034912                       1
# 2                0.178571               0.035714                       4
# 3                0.203896               0.036419                       2
# 4                0.189470               0.051793                       3
# 5                0.178571               0.035714                       4
# 6                0.178571               0.035714                       4
# 7                0.178571               0.035714                       4
# 8                0.178571               0.035714                       4
# 9                0.178571               0.035714                       4
#
# [10 rows x 42 columns]

# %%
for estimator in model_performance['estimator']:
    print(estimator.best_params_)
# Out:
# {'estimator__C': 730.0802536296363, 'estimator__gamma': 0.00038140351982047637}
# {'estimator__C': 10.73383078686751, 'estimator__gamma': 0.043109846869528234}
# {'estimator__C': 481.0264305619139, 'estimator__gamma': 0.05647762841969143}
# {'estimator__C': 821.2257586107107, 'estimator__gamma': 0.00846631455555496}
# {'estimator__C': 323.8403487917489, 'estimator__gamma': 0.002624289875121625}
# {'estimator__C': 88.04901633915712, 'estimator__gamma': 0.010059309419473828}
# {'estimator__C': 146.55709189215872, 'estimator__gamma': 0.003552611559285617}
# {'estimator__C': 11.528593234385763, 'estimator__gamma': 0.0740845762543288}
# {'estimator__C': 92.68982904403184, 'estimator__gamma': 0.012639295954616034}
# {'estimator__C': 654.6650492886708, 'estimator__gamma': 0.006010025633541435}

# %% [markdown]
# ##### We are going to track performance for
#
#  * Average performance across outer folds
#  * Perfomance on holdout of best hyper-params of each outer fold
#  * Average performance across inner folds of each hyper-param sample in each outer fold

# %%
import mlflow
from mlflow import log_metric, log_param

# Average performance across outer folds
with mlflow.start_run() as run:
    log_param('model_type', 'SVM')
    log_param('multilabel_type', 'independent')
    log_param('analysis_level', 'model_wide')
    for metric in [key for key in model_performance.keys() if 'test_' in key]:
        log_metric(f'{metric.split("test_")[1]}_mean', model_performance[metric].mean())
        log_metric(f'{metric.split("test_")[1]}_std', model_performance[metric].std())
        print(f'{metric.split("test_")[1]}_mean', model_performance[metric].mean())
        print(f'{metric.split("test_")[1]}_std', model_performance[metric].std())
mlflow.end_run()
# Out:
# f1_micro_mean 0.5357396628265825
# f1_micro_std 0.040584181119694314
# f1_macro_mean 0.3160875053852997
# f1_macro_std 0.025650922175171075
# accuracy_mean 0.0394291754756871
# accuracy_std 0.020897373142693826
# precision_micro_mean 0.6477434048874537
# precision_micro_std 0.09006295631796474
# precision_macro_mean 0.40472463068025444
# precision_macro_std 0.06497796647781344
# recall_micro_mean 0.46839462669974957
# recall_micro_std 0.06826704915116316
# recall_macro_mean 0.29547230499844773
# recall_macro_std 0.028297922313826863

# %%
# Hyperparam choice performance measured across outer folds
for fold_i in range(len(model_performance['estimator'])):
    with mlflow.start_run() as run:
        log_param('model_type', 'SVM')
        log_param('multilabel_type', 'independent')
        log_param('analysis_level', 'outer_cv')

        # Log the best hyper-paras found for fold_i values
        for key, value in model_performance['estimator'][fold_i].best_params_.items():
            log_param(key.split('__')[-1], value)

        # Log the metrics
        for metric in [key for key in model_performance.keys() if 'test_' in key]:
            log_metric(metric.split('test_')[1], model_performance[metric][fold_i])

    mlflow.end_run()

# %%
# Average performance across inner folds of the different hyper-param samples
for hyperparam_search in model_performance['estimator']:
        results_df = pd.DataFrame(hyperparam_search.cv_results_)
        metrics_mean_cols = [col for col in results_df.columns if 'mean_test' in col]
        metrics_std_cols = [col for col in results_df.columns if 'std_test' in col]

        for sample_i, hyperparam_sample_results in results_df.iterrows():
            with mlflow.start_run() as run:
                log_param('model_type', 'SVM')
                log_param('multilabel_type', 'independent')
                log_param('analysis_level', 'inner_cv')

                # Log the hyperparameters
                for param, param_value in hyperparam_sample_results.params.items():
                    log_param(param.split('__')[-1], param_value)

                # Log the metrics
                for mean_metric, std_metric in zip(metrics_mean_cols, metrics_std_cols):
                    log_metric(mean_metric, hyperparam_sample_results[mean_metric])
                    log_metric(std_metric, hyperparam_sample_results[std_metric])

            mlflow.end_run()
# Out:
# C 0.22622573283031963
# gamma 0.041094912743885305
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 730.0802536296363
# gamma 0.00038140351982047637
# mean_test_f1_micro 0.4817786886428912
# std_test_f1_micro 0.039810257816521616
# mean_test_f1_macro 0.23096107291008283
# std_test_f1_macro 0.013699488563011258
# mean_test_accuracy 0.02843063938892153
# std_test_accuracy 0.0026574435126328726
# mean_test_precision_micro 0.6629601226993865
# std_test_precision_micro 0.04537321063394684
# mean_test_precision_macro 0.3320399374025491
# std_test_precision_macro 0.030230951742512474
# mean_test_recall_micro 0.38630380712042267
# std_test_recall_micro 0.06511622277494358
# mean_test_recall_macro 0.21794973763875888
# std_test_recall_macro 0.03491213557639636
#
#
#
# C 0.22573658804182628
# gamma 0.006832306057007539
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 8.631637502243715
# gamma 0.022478151027060377
# mean_test_f1_micro 0.46730349592553583
# std_test_f1_micro 0.04533817800646062
# mean_test_f1_macro 0.2156300473920545
# std_test_f1_macro 0.012479608326867245
# mean_test_accuracy 0.018094653063404735
# std_test_accuracy 0.002630735537631537
# mean_test_precision_micro 0.6762182494400067
# std_test_precision_micro 0.0611554879337306
# mean_test_precision_macro 0.26977854009321667
# std_test_precision_macro 0.050210407996480425
# mean_test_recall_micro 0.36750422105626257
# std_test_recall_micro 0.07195766235180914
# mean_test_recall_macro 0.20389631053796803
# std_test_recall_macro 0.03641887103815064
#
#
#
# C 2.995992829648104
# gamma 0.026783196850554813
# mean_test_f1_micro 0.438312394072474
# std_test_f1_micro 0.06978649765813139
# mean_test_f1_macro 0.18409947259629977
# std_test_f1_macro 0.03774148358788852
# mean_test_accuracy 0.015544041450777202
# std_test_accuracy 0.015544041450777202
# mean_test_precision_micro 0.6473459472508902
# std_test_precision_micro 0.05607610598104895
# mean_test_precision_macro 0.25031385257471567
# std_test_precision_macro 0.03165893654093062
# mean_test_recall_micro 0.3475517873676949
# std_test_recall_micro 0.09788916928402415
# mean_test_recall_macro 0.18946993370034068
# std_test_recall_macro 0.051793060122702655
#
#
#
# C 0.2161763105544836
# gamma 0.0037542964071031935
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.3080838358481395
# gamma 0.000687758708522778
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.07410334600553543
# gamma 0.00089641349764506
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.010270589297712174
# gamma 0.007508168630570936
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 1.5619304706549475
# gamma 0.0005635765687945335
# mean_test_f1_micro 0.4025615475460471
# std_test_f1_micro 0.042951272966773424
# mean_test_f1_macro 0.11818996594717426
# std_test_f1_macro 0.02007753638745465
# mean_test_accuracy 0.0025906735751295338
# std_test_accuracy 0.0025906735751295338
# mean_test_precision_micro 0.501667022773
# std_test_precision_micro 0.02152885351565978
# mean_test_precision_macro 0.08881450929819071
# std_test_precision_macro 0.014072241256953617
# mean_test_recall_micro 0.34474985324643104
# std_test_recall_micro 0.07079573718705182
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 10.73383078686751
# gamma 0.043109846869528234
# mean_test_f1_micro 0.5264292062853214
# std_test_f1_micro 0.029925709781824933
# mean_test_f1_macro 0.27975251033959425
# std_test_f1_macro 0.009320831563966375
# mean_test_accuracy 0.04381443298969072
# std_test_accuracy 0.0025773195876288672
# mean_test_precision_micro 0.671795242440395
# std_test_precision_micro 0.06971911787292095
# mean_test_precision_macro 0.39456183064430833
# std_test_precision_macro 0.007420544748008684
# mean_test_recall_micro 0.44514041702381907
# std_test_recall_micro 0.07194725013814235
# mean_test_recall_macro 0.2617581982707519
# std_test_recall_macro 0.036220034734676096
#
#
#
# C 0.011488864020073543
# gamma 0.0004057836247515107
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 29.960572476075086
# gamma 0.00967969275062473
# mean_test_f1_micro 0.5028545890114123
# std_test_f1_micro 0.0399085688833245
# mean_test_f1_macro 0.24673373635739654
# std_test_f1_macro 0.01570066898794431
# mean_test_accuracy 0.03608247422680412
# std_test_accuracy 0.0
# mean_test_precision_micro 0.6848914997004594
# std_test_precision_micro 0.07715669307062506
# mean_test_precision_macro 0.3563441810009392
# std_test_precision_macro 0.02802591505159363
# mean_test_recall_micro 0.4113995231893594
# std_test_recall_micro 0.0789422301538798
# mean_test_recall_macro 0.23307950116759857
# std_test_recall_macro 0.042628957363253964
#
#
#
# C 0.2770902356947719
# gamma 0.08025242750222916
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.036147672682057395
# gamma 0.0033934282536534155
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 784.3852543010163
# gamma 0.03352468498524297
# mean_test_f1_micro 0.49336339432137877
# std_test_f1_micro 0.0032072503974140965
# mean_test_f1_macro 0.3479728933431175
# std_test_f1_macro 0.0048136577733509656
# mean_test_accuracy 0.01804123711340206
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.4840844843626995
# std_test_precision_micro 0.022937987547412886
# mean_test_precision_macro 0.3398663445409489
# std_test_precision_macro 0.021229513667468614
# mean_test_recall_micro 0.5061329329321511
# std_test_recall_micro 0.031757111644371894
# mean_test_recall_macro 0.37563814685367714
# std_test_recall_macro 0.014372203411941231
#
#
#
# C 0.011076416857333718
# gamma 0.0007901277830586523
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.21390965405130583
# gamma 0.0015013854414069338
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 837.1384836157993
# gamma 0.014603367430765162
# mean_test_f1_micro 0.4865430998022473
# std_test_f1_micro 0.0003172044854428957
# mean_test_f1_macro 0.34372225562221337
# std_test_f1_macro 0.0023971758269241694
# mean_test_accuracy 0.010309278350515464
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.48350683545252665
# std_test_precision_micro 0.030361777686159497
# mean_test_precision_macro 0.34273251355168344
# std_test_precision_macro 0.021465322778345758
# mean_test_recall_micro 0.4935331824669581
# std_test_recall_micro 0.03098390520020386
# mean_test_recall_macro 0.36625756317703595
# std_test_recall_macro 0.017293894293405276
#
#
#
# C 9.845229077927424
# gamma 0.00012569231737731112
# mean_test_f1_micro 0.40863317833973073
# std_test_f1_micro 0.03439471010648443
# mean_test_f1_macro 0.1198268366115702
# std_test_f1_macro 0.017959792764328332
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5158934707903781
# std_test_precision_micro 0.03823024054982818
# mean_test_precision_macro 0.09075846833578793
# std_test_precision_macro 0.01159793814432989
# mean_test_recall_micro 0.34779938807348587
# std_test_recall_micro 0.06527639201566718
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.08329724026706747
# gamma 0.006099455787051771
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 19.16176849162052
# gamma 0.0015757059207690495
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.013169451618185207
# gamma 0.006212756146525875
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.022936046603589874
# gamma 0.01787789240936483
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 534.9650450793297
# gamma 0.0003725688363601857
# mean_test_f1_micro 0.4764794957531035
# std_test_f1_micro 0.0508674430224067
# mean_test_f1_macro 0.22201284595993748
# std_test_f1_macro 0.015458165658846501
# mean_test_accuracy 0.01804123711340206
# std_test_accuracy 0.0025773195876288655
# mean_test_precision_micro 0.6704988851727982
# std_test_precision_micro 0.08535395763656634
# mean_test_precision_macro 0.31381377934250665
# std_test_precision_macro 0.010035717721276066
# mean_test_recall_micro 0.38806988913318236
# std_test_recall_micro 0.09187067550277606
# mean_test_recall_macro 0.21640557541424904
# std_test_recall_macro 0.048891068595868434
#
#
#
# C 481.0264305619139
# gamma 0.05647762841969143
# mean_test_f1_micro 0.49590771271423884
# std_test_f1_micro 0.00039356502617809985
# mean_test_f1_macro 0.3555317548771344
# std_test_f1_macro 0.0034889552894362963
# mean_test_accuracy 0.010309278350515464
# std_test_accuracy 0.010309278350515464
# mean_test_precision_micro 0.48614868713333714
# std_test_precision_micro 0.023519821153955678
# mean_test_precision_macro 0.3526259378713512
# std_test_precision_macro 0.011676666383408696
# mean_test_recall_micro 0.5085248462022322
# std_test_recall_micro 0.024907546071170544
# mean_test_recall_macro 0.37221515124347826
# std_test_recall_macro 0.00647210400468895
#
#
#
# C 11.141656676675362
# gamma 0.0004190370860873063
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.011822019760034677
# gamma 0.000251483684310552
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 1.3759746993547028
# gamma 0.012616763441635504
# mean_test_f1_micro 0.406570416855601
# std_test_f1_micro 0.036457471590614104
# mean_test_f1_macro 0.11951070412112817
# std_test_f1_macro 0.018275925254770356
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5133161512027492
# std_test_precision_micro 0.035652920962199325
# mean_test_precision_macro 0.09039027982326953
# std_test_precision_macro 0.011966126656848299
# mean_test_recall_micro 0.3461184929279317
# std_test_recall_micro 0.06695728716122135
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 11.273055005154989
# gamma 0.009078383969862651
# mean_test_f1_micro 0.4428997020854022
# std_test_f1_micro 0.08341608738828202
# mean_test_f1_macro 0.18944613138708793
# std_test_f1_macro 0.03416809683596923
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.6500683060109289
# std_test_precision_micro 0.09173497267759562
# mean_test_precision_macro 0.27542627954968707
# std_test_precision_macro 0.07350223553736461
# mean_test_recall_micro 0.36749633397533393
# std_test_recall_micro 0.1302748398731059
# mean_test_recall_macro 0.2017648301604374
# std_test_recall_macro 0.0682116859820166
#
#
#
# C 821.2257586107107
# gamma 0.00846631455555496
# mean_test_f1_micro 0.4844569609618507
# std_test_f1_micro 0.004400977756812252
# mean_test_f1_macro 0.3510751914933614
# std_test_f1_macro 0.01090760666420168
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.0025773195876288664
# mean_test_precision_micro 0.48986159100838
# std_test_precision_micro 0.02983537868858968
# mean_test_precision_macro 0.35783854439144946
# std_test_precision_macro 0.008952705978610948
# mean_test_recall_micro 0.4837895648040623
# std_test_recall_micro 0.037755754661019436
# mean_test_recall_macro 0.36285330341843214
# std_test_recall_macro 0.032831042480116174
#
#
#
# C 11.307534211392989
# gamma 0.023622886397599137
# mean_test_f1_micro 0.4689109406401264
# std_test_f1_micro 0.037071965342779595
# mean_test_f1_macro 0.23471867351209685
# std_test_f1_macro 0.014391201862030564
# mean_test_accuracy 0.03350515463917526
# std_test_accuracy 0.0025773195876288638
# mean_test_precision_micro 0.6619842511861291
# std_test_precision_micro 0.06641081054226594
# mean_test_precision_macro 0.37702836672812734
# std_test_precision_macro 0.06356258049547292
# mean_test_recall_micro 0.37335688076408063
# std_test_recall_micro 0.06646481314379454
# mean_test_recall_macro 0.21639160302139776
# std_test_recall_macro 0.03378208177271241
#
#
#
# C 13.976308398441613
# gamma 0.0001989088541897329
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.010324121230042935
# gamma 0.00023674292748232566
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.23839360821156533
# gamma 0.05378530799978259
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 4.623227788046269
# gamma 0.03982259459394343
# mean_test_f1_micro 0.4546489905676855
# std_test_f1_micro 0.047485936844782556
# mean_test_f1_macro 0.21512707492517982
# std_test_f1_macro 0.011356630050944172
# mean_test_accuracy 0.02577319587628866
# std_test_accuracy 0.010309278350515462
# mean_test_precision_micro 0.6650437365901964
# std_test_precision_micro 0.07468229080706384
# mean_test_precision_macro 0.32654334229375337
# std_test_precision_macro 0.0008129678048173494
# mean_test_recall_micro 0.3588670954926894
# std_test_recall_micro 0.07798283021310554
# mean_test_recall_macro 0.2041226352558389
# std_test_recall_macro 0.03730229094370589
#
#
#
# C 1.7121697603748256
# gamma 0.02180931231672038
# mean_test_f1_micro 0.3966947843153631
# std_test_f1_micro 0.048642836263415035
# mean_test_f1_macro 0.11852687590924861
# std_test_f1_macro 0.020693398295872703
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.5029196119887843
# std_test_precision_micro 0.01780577661225191
# mean_test_precision_macro 0.08936175174459787
# std_test_precision_macro 0.014972410515878408
# mean_test_recall_micro 0.33648415475608506
# std_test_recall_micro 0.07510574123202785
# mean_test_recall_macro 0.178237650200267
# std_test_recall_macro 0.03538050734312416
#
#
#
# C 0.08434236183801488
# gamma 0.013879045439081191
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 0.1979422167270615
# gamma 0.0004923033947936256
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 27.164985882807912
# gamma 0.00040254955890496
# mean_test_f1_micro 0.3952390954763487
# std_test_f1_micro 0.047788792969866434
# mean_test_f1_macro 0.11764395295778504
# std_test_f1_macro 0.02014267641811348
# mean_test_accuracy 0.002577319587628866
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.49785223367697595
# std_test_precision_micro 0.02018900343642613
# mean_test_precision_macro 0.08818114874815905
# std_test_precision_macro 0.014175257731958768
# mean_test_recall_micro 0.3372270968066051
# std_test_recall_micro 0.0758486832825479
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.03571428571428571
#
#
#
# C 38.238075487452264
# gamma 0.011114584370595504
# mean_test_f1_micro 0.4934514691644275
# std_test_f1_micro 0.04612849852539477
# mean_test_f1_macro 0.27013660112962523
# std_test_f1_macro 0.01766669993831091
# mean_test_accuracy 0.02577319587628866
# std_test_accuracy 0.005154639175257733
# mean_test_precision_micro 0.6446318250125229
# std_test_precision_micro 0.05348138253464685
# mean_test_precision_macro 0.3946910176069174
# std_test_precision_macro 0.0206814859393617
# mean_test_recall_micro 0.41269156482287395
# std_test_recall_micro 0.08359372492452577
# mean_test_recall_macro 0.2492225679897282
# std_test_recall_macro 0.0411633222381253
#
#
#
# C 28.473606506065213
# gamma 0.004582623706121907
# mean_test_f1_micro 0.439022445985924
# std_test_f1_micro 0.09043432524590453
# mean_test_f1_macro 0.19806200064174945
# std_test_f1_macro 0.0348572340388703
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.0025773195876288664
# mean_test_precision_micro 0.6457873291272345
# std_test_precision_micro 0.10004600420609883
# mean_test_precision_macro 0.3030399898986862
# std_test_precision_macro 0.03492108050790471
# mean_test_recall_micro 0.3707809482092925
# std_test_recall_micro 0.14333495075058855
# mean_test_recall_macro 0.2079169700749749
# std_test_recall_macro 0.07535826883133741
#
#
#
# C 565.541873461215
# gamma 0.07981285835543483
# mean_test_f1_micro 0.49261030311447973
# std_test_f1_micro 0.014320389954827178
# mean_test_f1_macro 0.3631409962374377
# std_test_f1_macro 0.012364379939607956
# mean_test_accuracy 0.010309278350515464
# std_test_accuracy 0.0
# mean_test_precision_micro 0.4801411796192834
# std_test_precision_micro 0.024084172493392647
# mean_test_precision_macro 0.35314916283172193
# std_test_precision_macro 0.013015130878939324
# mean_test_recall_micro 0.5127357448584068
# std_test_recall_micro 0.05784374994099886
# mean_test_recall_macro 0.38892512752931063
# std_test_recall_macro 0.04510360746858713
#
#
#
# C 8.419385808737042
# gamma 0.0010228095211097191
# mean_test_f1_micro 0.42717060922426325
# std_test_f1_micro 0.06972380071362494
# mean_test_f1_macro 0.1402779235201964
# std_test_f1_macro 0.03995177003789674
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5025773195876289
# std_test_precision_micro 0.03865979381443296
# mean_test_precision_macro 0.1049337260677467
# std_test_precision_macro 0.0276141384388807
# mean_test_recall_micro 0.40087718138925443
# std_test_recall_micro 0.13404109498518835
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.09916540112426578
# gamma 0.0018966765093798924
# mean_test_f1_micro 0.42717060922426325
# std_test_f1_micro 0.06972380071362494
# mean_test_f1_macro 0.1402779235201964
# std_test_f1_macro 0.03995177003789674
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5025773195876289
# std_test_precision_micro 0.03865979381443296
# mean_test_precision_macro 0.1049337260677467
# std_test_precision_macro 0.0276141384388807
# mean_test_recall_micro 0.40087718138925443
# std_test_recall_micro 0.13404109498518835
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 323.8403487917489
# gamma 0.002624289875121625
# mean_test_f1_micro 0.5206303180713129
# std_test_f1_micro 0.024682181928687236
# mean_test_f1_macro 0.30401140258370335
# std_test_f1_macro 0.004975877003557394
# mean_test_accuracy 0.02577319587628866
# std_test_accuracy 0.005154639175257733
# mean_test_precision_micro 0.629761286113906
# std_test_precision_micro 0.05480247227535573
# mean_test_precision_macro 0.3790389577140303
# std_test_precision_macro 0.02500588703452597
# mean_test_recall_micro 0.4536959242973203
# std_test_recall_micro 0.0648776269656812
# mean_test_recall_macro 0.2830796502193087
# std_test_recall_macro 0.029907447888675553
#
#
#
# C 11.2240741937819
# gamma 0.00014696548614037054
# mean_test_f1_micro 0.42717060922426325
# std_test_f1_micro 0.06972380071362494
# mean_test_f1_macro 0.1402779235201964
# std_test_f1_macro 0.03995177003789674
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5025773195876289
# std_test_precision_micro 0.03865979381443296
# mean_test_precision_macro 0.1049337260677467
# std_test_precision_macro 0.0276141384388807
# mean_test_recall_micro 0.40087718138925443
# std_test_recall_micro 0.13404109498518835
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 326.7295385567245
# gamma 0.00025833864794188997
# mean_test_f1_micro 0.43522183042245793
# std_test_f1_micro 0.09733120542245793
# mean_test_f1_macro 0.18192870917518483
# std_test_f1_macro 0.04062358572720427
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.6272267415703012
# std_test_precision_micro 0.10273106433687179
# mean_test_precision_macro 0.24270390928245383
# std_test_precision_macro 0.04824103119373664
# mean_test_recall_micro 0.38034196102716694
# std_test_recall_micro 0.16051985175143632
# mean_test_recall_macro 0.20903824626236361
# std_test_recall_macro 0.0844508562585608
#
#
#
# C 22.05377071844829
# gamma 0.00016296464010311944
# mean_test_f1_micro 0.42717060922426325
# std_test_f1_micro 0.06972380071362494
# mean_test_f1_macro 0.1402779235201964
# std_test_f1_macro 0.03995177003789674
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5025773195876289
# std_test_precision_micro 0.03865979381443296
# mean_test_precision_macro 0.1049337260677467
# std_test_precision_macro 0.0276141384388807
# mean_test_recall_micro 0.40087718138925443
# std_test_recall_micro 0.13404109498518835
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 2.0055496902282806
# gamma 0.057585660430442796
# mean_test_f1_micro 0.4363562219414598
# std_test_f1_micro 0.09747277434106799
# mean_test_f1_macro 0.1902564343299926
# std_test_f1_macro 0.038457093986414836
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.002577319587628866
# mean_test_precision_micro 0.6367712148962149
# std_test_precision_micro 0.10254502442002444
# mean_test_precision_macro 0.2709011576360631
# std_test_precision_macro 0.07703701530210981
# mean_test_recall_micro 0.37662725077456666
# std_test_recall_micro 0.15680514149883604
# mean_test_recall_macro 0.20963058682271304
# std_test_recall_macro 0.081699137576315
#
#
#
# C 0.5604974317664109
# gamma 0.04136252034521008
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.44401266350679386
# gamma 0.00045698060791039304
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 166.34168348034748
# gamma 0.00010889639614062159
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.2512340742230788
# gamma 0.0005168768355711443
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 88.04901633915712
# gamma 0.010059309419473828
# mean_test_f1_micro 0.522074542243703
# std_test_f1_micro 0.03767388542925304
# mean_test_f1_macro 0.30865207991771443
# std_test_f1_macro 0.018343660398942085
# mean_test_accuracy 0.03865979381443299
# std_test_accuracy 0.0025773195876288672
# mean_test_precision_micro 0.6238067838120952
# std_test_precision_micro 0.0421074374068664
# mean_test_precision_macro 0.40949899192175565
# std_test_precision_macro 0.03636963296986773
# mean_test_recall_micro 0.460019550342131
# std_test_recall_micro 0.07937438905180844
# mean_test_recall_macro 0.28797842545021657
# std_test_recall_macro 0.0426843864429655
#
#
#
# C 0.4577657739901867
# gamma 0.006659758970555081
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.01189647736951038
# gamma 0.0033007591849534834
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 21.022447569499672
# gamma 0.02350499430270189
# mean_test_f1_micro 0.5133394657792766
# std_test_f1_micro 0.036985209545398745
# mean_test_f1_macro 0.2739259031455492
# std_test_f1_macro 0.008586389389082266
# mean_test_accuracy 0.03608247422680412
# std_test_accuracy 0.0
# mean_test_precision_micro 0.6532874342152692
# std_test_precision_micro 0.06063009155792659
# mean_test_precision_macro 0.3869475090622506
# std_test_precision_macro 0.028769627739133413
# mean_test_recall_micro 0.4355278592375367
# std_test_recall_micro 0.078108504398827
# mean_test_recall_macro 0.2549079887124827
# std_test_recall_macro 0.03561112605466499
#
#
#
# C 1.6987375763430606
# gamma 0.0005959311693878072
# mean_test_f1_micro 0.4292172534292017
# std_test_f1_micro 0.07496101955129972
# mean_test_f1_macro 0.1399968832433553
# std_test_f1_macro 0.0409192475408117
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49871134020618557
# std_test_precision_micro 0.03221649484536082
# mean_test_precision_macro 0.10456553755522827
# std_test_precision_macro 0.028718703976435937
# mean_test_recall_micro 0.4071456500488758
# std_test_recall_micro 0.14133919843597262
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 316.6598136188734
# gamma 0.052638712296584664
# mean_test_f1_micro 0.5098144887053679
# std_test_f1_micro 0.012531880009715779
# mean_test_f1_macro 0.37195496117510385
# std_test_f1_macro 0.016664880335887478
# mean_test_accuracy 0.015463917525773196
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5047817812832197
# std_test_precision_micro 0.02032582273399694
# mean_test_precision_macro 0.36764347751877824
# std_test_precision_macro 0.006114388185330666
# mean_test_recall_micro 0.5194623655913978
# std_test_recall_micro 0.04720430107526882
# mean_test_recall_macro 0.38946473184156727
# std_test_recall_macro 0.04386210296907575
#
#
#
# C 100.64644138773455
# gamma 0.07256396798433432
# mean_test_f1_micro 0.4871367171510438
# std_test_f1_micro 0.008565288579615221
# mean_test_f1_macro 0.34126881857747543
# std_test_f1_macro 0.011656210200032435
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.0025773195876288664
# mean_test_precision_micro 0.49774767596281544
# std_test_precision_micro 0.03825232403718462
# mean_test_precision_macro 0.34915373988658294
# std_test_precision_macro 0.01808886231114168
# mean_test_recall_micro 0.48518035418652483
# std_test_recall_micro 0.052922289670395806
# mean_test_recall_macro 0.35753182653445537
# std_test_recall_macro 0.051861866552130126
#
#
#
# C 0.6841124254471072
# gamma 0.011682627340820798
# mean_test_f1_micro 0.35652151146427197
# std_test_f1_micro 0.14805917916293038
# mean_test_f1_macro 0.11420357591941524
# std_test_f1_macro 0.0652931642971392
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.490979381443299
# std_test_precision_micro 0.029639175257731964
# mean_test_precision_macro 0.08449926362297497
# std_test_precision_macro 0.04731222385861562
# mean_test_recall_micro 0.34354387197110314
# std_test_recall_micro 0.2132212913259419
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.10714285714285714
#
#
#
# C 109.19289035527008
# gamma 0.0019029163757180226
# mean_test_f1_micro 0.4519623185737519
# std_test_f1_micro 0.08159194820338148
# mean_test_f1_macro 0.21327779168228156
# std_test_f1_macro 0.03459158723449356
# mean_test_accuracy 0.01804123711340206
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.6639470486846939
# std_test_precision_micro 0.09302506286909101
# mean_test_precision_macro 0.3514498813927257
# std_test_precision_macro 0.013397087982789407
# mean_test_recall_micro 0.37296944764962625
# std_test_recall_micro 0.12780815732704562
# mean_test_recall_macro 0.20736964837036526
# std_test_recall_macro 0.06569627373296026
#
#
#
# C 1.0632086374890155
# gamma 0.06533817322714099
# mean_test_f1_micro 0.38163716814159293
# std_test_f1_micro 0.13163716814159293
# mean_test_f1_macro 0.13840408350762415
# std_test_f1_macro 0.05827455566439921
# mean_test_accuracy 0.010309278350515464
# std_test_accuracy 0.010309278350515464
# mean_test_precision_micro 0.5575107732779105
# std_test_precision_micro 0.06943223190343656
# mean_test_precision_macro 0.18055749330500362
# std_test_precision_macro 0.003966316218805915
# mean_test_recall_micro 0.3486710480108363
# std_test_recall_micro 0.1925420157527718
# mean_test_recall_macro 0.18333722650364334
# std_test_recall_macro 0.09838403730717267
#
#
#
# C 146.55709189215872
# gamma 0.003552611559285617
# mean_test_f1_micro 0.4973592709067267
# std_test_f1_micro 0.04512438922399223
# mean_test_f1_macro 0.2600721160605882
# std_test_f1_macro 0.02477124967918115
# mean_test_accuracy 0.03092783505154639
# std_test_accuracy 0.005154639175257731
# mean_test_precision_micro 0.6381733021077283
# std_test_precision_micro 0.06674473067915693
# mean_test_precision_macro 0.3655251624329406
# std_test_precision_macro 0.01167975900601137
# mean_test_recall_micro 0.4246164651582802
# std_test_recall_micro 0.09171323935182862
# mean_test_recall_macro 0.24383289950376374
# std_test_recall_macro 0.049134260621204226
#
#
#
# C 0.07259811596623104
# gamma 0.000638142047227281
# mean_test_f1_micro 0.35652151146427197
# std_test_f1_micro 0.14805917916293038
# mean_test_f1_macro 0.11420357591941524
# std_test_f1_macro 0.0652931642971392
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.490979381443299
# std_test_precision_micro 0.029639175257731964
# mean_test_precision_macro 0.08449926362297497
# std_test_precision_macro 0.04731222385861562
# mean_test_recall_micro 0.34354387197110314
# std_test_recall_micro 0.2132212913259419
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.10714285714285714
#
#
#
# C 0.044953081873641
# gamma 0.00013473819653108437
# mean_test_f1_micro 0.35652151146427197
# std_test_f1_micro 0.14805917916293038
# mean_test_f1_macro 0.11420357591941524
# std_test_f1_macro 0.0652931642971392
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.490979381443299
# std_test_precision_micro 0.029639175257731964
# mean_test_precision_macro 0.08449926362297497
# std_test_precision_macro 0.04731222385861562
# mean_test_recall_micro 0.34354387197110314
# std_test_recall_micro 0.2132212913259419
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.10714285714285714
#
#
#
# C 17.26221617370844
# gamma 0.000584848139563835
# mean_test_f1_micro 0.35652151146427197
# std_test_f1_micro 0.14805917916293038
# mean_test_f1_macro 0.11420357591941524
# std_test_f1_macro 0.0652931642971392
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.490979381443299
# std_test_precision_micro 0.029639175257731964
# mean_test_precision_macro 0.08449926362297497
# std_test_precision_macro 0.04731222385861562
# mean_test_recall_micro 0.34354387197110314
# std_test_recall_micro 0.2132212913259419
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.10714285714285714
#
#
#
# C 6.318982709874599
# gamma 0.032616604070409345
# mean_test_f1_micro 0.4531123562046442
# std_test_f1_micro 0.08165585571588563
# mean_test_f1_macro 0.21380735807284834
# std_test_f1_macro 0.03437395013704775
# mean_test_accuracy 0.01804123711340206
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.668905224093634
# std_test_precision_micro 0.09722380816443049
# mean_test_precision_macro 0.3559847695762154
# std_test_precision_macro 0.009048355150305137
# mean_test_recall_micro 0.3737470526262981
# std_test_recall_micro 0.1285857623037175
# mean_test_recall_macro 0.20774172723666118
# std_test_recall_macro 0.06606835259925618
#
#
#
# C 0.3319377005748732
# gamma 0.00016473203944626899
# mean_test_f1_micro 0.35652151146427197
# std_test_f1_micro 0.14805917916293038
# mean_test_f1_macro 0.11420357591941524
# std_test_f1_macro 0.0652931642971392
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.490979381443299
# std_test_precision_micro 0.029639175257731964
# mean_test_precision_macro 0.08449926362297497
# std_test_precision_macro 0.04731222385861562
# mean_test_recall_micro 0.34354387197110314
# std_test_recall_micro 0.2132212913259419
# mean_test_recall_macro 0.17857142857142855
# std_test_recall_macro 0.10714285714285714
#
#
#
# C 21.954844195250605
# gamma 0.09168855847514143
# mean_test_f1_micro 0.5259387887996527
# std_test_f1_micro 0.015237681788582591
# mean_test_f1_macro 0.3299111894357811
# std_test_f1_macro 0.013049169063087035
# mean_test_accuracy 0.03865979381443299
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.5809179511626674
# std_test_precision_micro 0.015633772975263527
# mean_test_precision_macro 0.40103720559239575
# std_test_precision_macro 0.024827940386486197
# mean_test_recall_micro 0.48274625779152824
# std_test_recall_micro 0.036294644888302446
# mean_test_recall_macro 0.3121111145904538
# std_test_recall_macro 0.02604954220826411
#
#
#
# C 462.68762358193294
# gamma 0.028272627048508407
# mean_test_f1_micro 0.4964795566046677
# std_test_f1_micro 0.006546670698627438
# mean_test_f1_macro 0.36652818715539104
# std_test_f1_macro 0.008938418951794286
# mean_test_accuracy 0.015463917525773196
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.49560465241699175
# std_test_precision_micro 0.01488485807251877
# mean_test_precision_macro 0.3658183825579815
# std_test_precision_macro 0.004282988453348541
# mean_test_recall_micro 0.49923563401428633
# std_test_recall_micro 0.02826789207880248
# mean_test_recall_macro 0.37625197883979405
# std_test_recall_macro 0.02425523504776783
#
#
#
# C 831.0453518584416
# gamma 0.09154042600691288
# mean_test_f1_micro 0.4933448770575592
# std_test_f1_micro 0.008657793169410122
# mean_test_f1_macro 0.3618459829352779
# std_test_f1_macro 0.01090604067795195
# mean_test_accuracy 0.010309278350515464
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.488620178067409
# std_test_precision_micro 0.012067579841806952
# mean_test_precision_macro 0.361003618066283
# std_test_precision_macro 0.0027395186907733515
# mean_test_recall_micro 0.5000009099595067
# std_test_recall_micro 0.030323490604668074
# mean_test_recall_macro 0.3714851788141191
# std_test_recall_macro 0.025366208827730885
#
#
#
# C 0.06905732874504648
# gamma 0.09199391797510909
# mean_test_f1_micro 0.4336937735046076
# std_test_f1_micro 0.07943753962670555
# mean_test_f1_macro 0.14332038495427646
# std_test_f1_macro 0.044242749251732855
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.5109536082474226
# std_test_precision_micro 0.019974226804123724
# mean_test_precision_macro 0.10806332842415317
# std_test_precision_macro 0.03221649484536083
# mean_test_recall_micro 0.40159151917739666
# std_test_recall_micro 0.1357850675644934
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 11.528593234385763
# gamma 0.0740845762543288
# mean_test_f1_micro 0.535372563447714
# std_test_f1_micro 0.018991908221504983
# mean_test_f1_macro 0.30355890655056145
# std_test_f1_macro 0.008291437120555023
# mean_test_accuracy 0.028350515463917522
# std_test_accuracy 0.0077319587628865965
# mean_test_precision_micro 0.6296125598406233
# std_test_precision_micro 0.023247400711644994
# mean_test_precision_macro 0.40347951530255216
# std_test_precision_macro 0.033254529392777066
# mean_test_recall_micro 0.4688375267300605
# std_test_recall_micro 0.041740752536512105
# mean_test_recall_macro 0.2837889129788804
# std_test_recall_macro 0.02129262822751818
#
#
#
# C 990.7724561931597
# gamma 0.00014485403444830083
# mean_test_f1_micro 0.4934123720276218
# std_test_f1_micro 0.04818888385934836
# mean_test_f1_macro 0.2241442315176264
# std_test_f1_macro 0.015902840785850428
# mean_test_accuracy 0.023195876288659795
# std_test_accuracy 0.0025773195876288655
# mean_test_precision_micro 0.6523042700324
# std_test_precision_micro 0.04168480100585137
# mean_test_precision_macro 0.28260795137390615
# std_test_precision_macro 0.026546535526709242
# mean_test_recall_micro 0.40717139087310616
# std_test_recall_micro 0.07942945538923518
# mean_test_recall_macro 0.2261467354427646
# std_test_recall_macro 0.03899601671836729
#
#
#
# C 214.98031960894963
# gamma 0.009030547319415924
# mean_test_f1_micro 0.5210891786388698
# std_test_f1_micro 0.012639509278105643
# mean_test_f1_macro 0.3294570854346802
# std_test_f1_macro 0.009879120730075824
# mean_test_accuracy 0.03608247422680412
# std_test_accuracy 0.005154639175257731
# mean_test_precision_micro 0.576471843003413
# std_test_precision_micro 0.013971843003412976
# mean_test_precision_macro 0.38279816281905377
# std_test_precision_macro 0.006376534963910746
# mean_test_recall_micro 0.4771045088493562
# std_test_recall_micro 0.030652895946130382
# mean_test_recall_macro 0.3102391514374375
# std_test_recall_macro 0.021685387415907892
#
#
#
# C 3.52844379831847
# gamma 0.001029976050821827
# mean_test_f1_micro 0.4336937735046076
# std_test_f1_micro 0.07943753962670555
# mean_test_f1_macro 0.14332038495427646
# std_test_f1_macro 0.044242749251732855
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.5109536082474226
# std_test_precision_micro 0.019974226804123724
# mean_test_precision_macro 0.10806332842415317
# std_test_precision_macro 0.03221649484536083
# mean_test_recall_micro 0.40159151917739666
# std_test_recall_micro 0.1357850675644934
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.3744195813151749
# gamma 0.0006438275348588494
# mean_test_f1_micro 0.4336937735046076
# std_test_f1_micro 0.07943753962670555
# mean_test_f1_macro 0.14332038495427646
# std_test_f1_macro 0.044242749251732855
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.5109536082474226
# std_test_precision_micro 0.019974226804123724
# mean_test_precision_macro 0.10806332842415317
# std_test_precision_macro 0.03221649484536083
# mean_test_recall_micro 0.40159151917739666
# std_test_recall_micro 0.1357850675644934
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 42.08733539126187
# gamma 0.00011518611182169815
# mean_test_f1_micro 0.4336937735046076
# std_test_f1_micro 0.07943753962670555
# mean_test_f1_macro 0.14332038495427646
# std_test_f1_macro 0.044242749251732855
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.5109536082474226
# std_test_precision_micro 0.019974226804123724
# mean_test_precision_macro 0.10806332842415317
# std_test_precision_macro 0.03221649484536083
# mean_test_recall_micro 0.40159151917739666
# std_test_recall_micro 0.1357850675644934
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 668.3327452053148
# gamma 0.03397725961412017
# mean_test_f1_micro 0.5093260129690729
# std_test_f1_micro 0.008995106284757803
# mean_test_f1_macro 0.3857989959258903
# std_test_f1_macro 0.009964006657736807
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.49901016568303647
# std_test_precision_micro 0.014576790838702697
# mean_test_precision_macro 0.38812115482943177
# std_test_precision_macro 0.013247879976777899
# mean_test_recall_micro 0.5225242628708753
# std_test_recall_micro 0.03478232738700435
# mean_test_recall_macro 0.4025425044291818
# std_test_recall_macro 0.02879947058006377
#
#
#
# C 0.030278127715143772
# gamma 0.012384038940565893
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.13522828038193488
# gamma 0.0038559648305159246
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 1.7603819732597645
# gamma 0.00784257250081726
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 144.95559733612106
# gamma 0.0003490380457170917
# mean_test_f1_micro 0.4352039858719948
# std_test_f1_micro 0.06965038306004401
# mean_test_f1_macro 0.1515723680219372
# std_test_f1_macro 0.040186078448123705
# mean_test_accuracy 0.01288659793814433
# std_test_accuracy 0.0025773195876288664
# mean_test_precision_micro 0.5311250333244468
# std_test_precision_micro 0.04187772149648983
# mean_test_precision_macro 0.16862887720527953
# std_test_precision_macro 0.01611121942446385
# mean_test_recall_micro 0.3949385340604492
# std_test_recall_micro 0.12655143728625565
# mean_test_recall_macro 0.2148176212179041
# std_test_recall_macro 0.07070770002170289
#
#
#
# C 0.019328563537777902
# gamma 0.007683121969442932
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.1314762708084989
# gamma 0.03936485133464837
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 0.32073364471903604
# gamma 0.0537761505092971
# mean_test_f1_micro 0.42475362575848963
# std_test_f1_micro 0.07049739188058765
# mean_test_f1_macro 0.1404547993160065
# std_test_f1_macro 0.04137716361346289
# mean_test_accuracy 0.005154639175257732
# std_test_accuracy 0.005154639175257732
# mean_test_precision_micro 0.5006443298969072
# std_test_precision_micro 0.03028350515463918
# mean_test_precision_macro 0.1051178203240059
# std_test_precision_macro 0.029270986745213563
# mean_test_recall_micro 0.39436454385802755
# std_test_recall_micro 0.1285580922451243
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 92.68982904403184
# gamma 0.012639295954616034
# mean_test_f1_micro 0.5288909971276541
# std_test_f1_micro 0.016977084752558158
# mean_test_f1_macro 0.3240836616581483
# std_test_f1_macro 0.0012314484418301241
# mean_test_accuracy 0.030927835051546393
# std_test_accuracy 0.0
# mean_test_precision_micro 0.6063949964181408
# std_test_precision_micro 0.02668485149060451
# mean_test_precision_macro 0.38426200050261894
# std_test_precision_macro 0.024739400170216974
# mean_test_recall_micro 0.4727183658378778
# std_test_recall_micro 0.04304094648303908
# mean_test_recall_macro 0.30453152758486873
# std_test_recall_macro 0.023031454982056332
#
#
#
# C 797.8228139867069
# gamma 0.04180518732370714
# mean_test_f1_micro 0.507341549959109
# std_test_f1_micro 0.009002679527215285
# mean_test_f1_macro 0.3824673804796559
# std_test_f1_macro 0.008446567490712875
# mean_test_accuracy 0.01804123711340206
# std_test_accuracy 0.007731958762886597
# mean_test_precision_micro 0.4984223487763584
# std_test_precision_micro 0.015276281360628002
# mean_test_precision_macro 0.3850452229739322
# std_test_precision_macro 0.015419223949398209
# mean_test_recall_micro 0.5191561142434606
# std_test_recall_micro 0.03528514650152509
# mean_test_recall_macro 0.3975237442797266
# std_test_recall_macro 0.02746917549432515
#
#
#
# C 0.028252711809263854
# gamma 0.0002970526595563345
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 5.147322027866218
# gamma 0.005680510857114379
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 270.4185202718763
# gamma 0.017644661436944542
# mean_test_f1_micro 0.5086250396505868
# std_test_f1_micro 0.014883732279237782
# mean_test_f1_macro 0.37217146229415077
# std_test_f1_macro 0.012476856389809554
# mean_test_accuracy 0.028350515463917526
# std_test_accuracy 0.01288659793814433
# mean_test_precision_micro 0.5204325007050976
# std_test_precision_micro 0.015012446504555521
# mean_test_precision_macro 0.3858048430024066
# std_test_precision_macro 0.002235062152838807
# mean_test_recall_micro 0.5005024181809644
# std_test_recall_micro 0.04243790205193218
# mean_test_recall_macro 0.37962798442120016
# std_test_recall_macro 0.026468052795368704
#
#
#
# C 0.31695727144263397
# gamma 0.0010022242786233134
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 654.6650492886708
# gamma 0.006010025633541435
# mean_test_f1_micro 0.5157169484622129
# std_test_f1_micro 0.019233122864463298
# mean_test_f1_macro 0.3751810537139655
# std_test_f1_macro 0.012983785624189226
# mean_test_accuracy 0.02577319587628866
# std_test_accuracy 0.005154639175257733
# mean_test_precision_micro 0.5350352892856757
# std_test_precision_micro 0.010559764810151195
# mean_test_precision_macro 0.3979423782670606
# std_test_precision_macro 0.006962397763443928
# mean_test_recall_micro 0.5006676996760108
# std_test_recall_micro 0.045183828708268786
# mean_test_recall_macro 0.37711623585646814
# std_test_recall_macro 0.026010195093912725
#
#
#
# C 3.3625922133372432
# gamma 0.0013906167011028677
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 13.915514432423944
# gamma 0.004247584083367669
# mean_test_f1_micro 0.4325488290634266
# std_test_f1_micro 0.07669725913002987
# mean_test_f1_macro 0.16221467335517317
# std_test_f1_macro 0.041772389858702484
# mean_test_accuracy 0.015463917525773195
# std_test_accuracy 0.010309278350515464
# mean_test_precision_micro 0.5877250005039205
# std_test_precision_micro 0.08981123138013747
# mean_test_precision_macro 0.1803776056208573
# std_test_precision_macro 0.013955139198390865
# mean_test_recall_micro 0.38119829083908535
# std_test_recall_micro 0.13990796825844018
# mean_test_recall_macro 0.20817723965964308
# std_test_recall_macro 0.07848774009744193
#
#
#
# C 1.0388206153113342
# gamma 0.005711839383665316
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142
#
#
#
# C 27.201040931945492
# gamma 0.015143718827862493
# mean_test_f1_micro 0.5101514698657762
# std_test_f1_micro 0.032820417684424646
# mean_test_f1_macro 0.28200765762491636
# std_test_f1_macro 0.0013741956747927442
# mean_test_accuracy 0.03092783505154639
# std_test_accuracy 0.005154639175257731
# mean_test_precision_micro 0.6569282972181285
# std_test_precision_micro 0.051193530193038905
# mean_test_precision_macro 0.39655195882640315
# std_test_precision_macro 0.012721298288318722
# mean_test_recall_micro 0.4259970887918486
# std_test_recall_micro 0.06599708879184862
# mean_test_recall_macro 0.2593930944232251
# std_test_recall_macro 0.030599437957867973
#
#
#
# C 0.021350956162638095
# gamma 0.024272667559715615
# mean_test_f1_micro 0.4231978366928813
# std_test_f1_micro 0.0689416028149793
# mean_test_f1_macro 0.13977776326190247
# std_test_f1_macro 0.04070012755935889
# mean_test_accuracy 0.007731958762886598
# std_test_accuracy 0.007731958762886598
# mean_test_precision_micro 0.49742268041237114
# std_test_precision_micro 0.03350515463917525
# mean_test_precision_macro 0.10419734904270986
# std_test_precision_macro 0.02835051546391753
# mean_test_recall_micro 0.39491195943090573
# std_test_recall_micro 0.12910550781800254
# mean_test_recall_macro 0.21428571428571427
# std_test_recall_macro 0.07142857142857142

# %%
model_performance['estimator'][0].cv_results_
# Out:
# {'mean_fit_time': array([0.02479637, 0.02219582, 0.01984251, 0.02333748, 0.02201629,
#         0.01939094, 0.01767337, 0.02010703, 0.01761436, 0.01871419]),
#  'std_fit_time': array([4.98652458e-04, 9.60111618e-04, 3.32713127e-04, 9.21368599e-04,
#         6.36577606e-05, 6.03795052e-04, 1.15036964e-04, 1.60789490e-03,
#         6.49452209e-04, 1.20425224e-03]),
#  'mean_score_time': array([0.02690673, 0.02395713, 0.02455914, 0.02921712, 0.02782238,
#         0.02360904, 0.02243257, 0.02504301, 0.02464771, 0.02501631]),
#  'std_score_time': array([0.00154757, 0.00127351, 0.00166762, 0.00211132, 0.00245416,
#         0.00073588, 0.00037646, 0.00123453, 0.00093412, 0.00151277]),
#  'param_estimator__C': masked_array(data=[0.22622573283031963, 730.0802536296363,
#                     0.22573658804182628, 8.631637502243715,
#                     2.995992829648104, 0.2161763105544836,
#                     0.3080838358481395, 0.07410334600553543,
#                     0.010270589297712174, 1.5619304706549475],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_estimator__gamma': masked_array(data=[0.041094912743885305, 0.00038140351982047637,
#                     0.006832306057007539, 0.022478151027060377,
#                     0.026783196850554813, 0.0037542964071031935,
#                     0.000687758708522778, 0.00089641349764506,
#                     0.007508168630570936, 0.0005635765687945335],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'estimator__C': 0.22622573283031963,
#    'estimator__gamma': 0.041094912743885305},
#   {'estimator__C': 730.0802536296363,
#    'estimator__gamma': 0.00038140351982047637},
#   {'estimator__C': 0.22573658804182628,
#    'estimator__gamma': 0.006832306057007539},
#   {'estimator__C': 8.631637502243715,
#    'estimator__gamma': 0.022478151027060377},
#   {'estimator__C': 2.995992829648104,
#    'estimator__gamma': 0.026783196850554813},
#   {'estimator__C': 0.2161763105544836,
#    'estimator__gamma': 0.0037542964071031935},
#   {'estimator__C': 0.3080838358481395,
#    'estimator__gamma': 0.000687758708522778},
#   {'estimator__C': 0.07410334600553543,
#    'estimator__gamma': 0.00089641349764506},
#   {'estimator__C': 0.010270589297712174,
#    'estimator__gamma': 0.007508168630570936},
#   {'estimator__C': 1.5619304706549475,
#    'estimator__gamma': 0.0005635765687945335}],
#  'split0_test_f1_micro': array([0.35961027, 0.44196843, 0.35961027, 0.42196532, 0.3685259 ,
#         0.35961027, 0.35961027, 0.35961027, 0.35961027, 0.35961027]),
#  'split1_test_f1_micro': array([0.44551282, 0.52158895, 0.44551282, 0.51264167, 0.50809889,
#         0.44551282, 0.44551282, 0.44551282, 0.44551282, 0.44551282]),
#  'mean_test_f1_micro': array([0.40256155, 0.48177869, 0.40256155, 0.4673035 , 0.43831239,
#         0.40256155, 0.40256155, 0.40256155, 0.40256155, 0.40256155]),
#  'std_test_f1_micro': array([0.04295127, 0.03981026, 0.04295127, 0.04533818, 0.0697865 ,
#         0.04295127, 0.04295127, 0.04295127, 0.04295127, 0.04295127]),
#  'rank_test_f1_micro': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_f1_macro': array([0.09811243, 0.21726158, 0.09811243, 0.20315044, 0.14635799,
#         0.09811243, 0.09811243, 0.09811243, 0.09811243, 0.09811243]),
#  'split1_test_f1_macro': array([0.1382675 , 0.24466056, 0.1382675 , 0.22810966, 0.22184096,
#         0.1382675 , 0.1382675 , 0.1382675 , 0.1382675 , 0.1382675 ]),
#  'mean_test_f1_macro': array([0.11818997, 0.23096107, 0.11818997, 0.21563005, 0.18409947,
#         0.11818997, 0.11818997, 0.11818997, 0.11818997, 0.11818997]),
#  'std_test_f1_macro': array([0.02007754, 0.01369949, 0.02007754, 0.01247961, 0.03774148,
#         0.02007754, 0.02007754, 0.02007754, 0.02007754, 0.02007754]),
#  'rank_test_f1_macro': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_accuracy': array([0.        , 0.0257732 , 0.        , 0.01546392, 0.        ,
#         0.        , 0.        , 0.        , 0.        , 0.        ]),
#  'split1_test_accuracy': array([0.00518135, 0.03108808, 0.00518135, 0.02072539, 0.03108808,
#         0.00518135, 0.00518135, 0.00518135, 0.00518135, 0.00518135]),
#  'mean_test_accuracy': array([0.00259067, 0.02843064, 0.00259067, 0.01809465, 0.01554404,
#         0.00259067, 0.00259067, 0.00259067, 0.00259067, 0.00259067]),
#  'std_test_accuracy': array([0.00259067, 0.00265744, 0.00259067, 0.00263074, 0.01554404,
#         0.00259067, 0.00259067, 0.00259067, 0.00259067, 0.00259067]),
#  'rank_test_accuracy': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_precision_micro': array([0.52319588, 0.70833333, 0.52319588, 0.73737374, 0.70342205,
#         0.52319588, 0.52319588, 0.52319588, 0.52319588, 0.52319588]),
#  'split1_test_precision_micro': array([0.48013817, 0.61758691, 0.48013817, 0.61506276, 0.59126984,
#         0.48013817, 0.48013817, 0.48013817, 0.48013817, 0.48013817]),
#  'mean_test_precision_micro': array([0.50166702, 0.66296012, 0.50166702, 0.67621825, 0.64734595,
#         0.50166702, 0.50166702, 0.50166702, 0.50166702, 0.50166702]),
#  'std_test_precision_micro': array([0.02152885, 0.04537321, 0.02152885, 0.06115549, 0.05607611,
#         0.02152885, 0.02152885, 0.02152885, 0.02152885, 0.02152885]),
#  'rank_test_precision_micro': array([4, 2, 4, 1, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_precision_macro': array([0.07474227, 0.30180899, 0.07474227, 0.31998895, 0.28197279,
#         0.07474227, 0.07474227, 0.07474227, 0.07474227, 0.07474227]),
#  'split1_test_precision_macro': array([0.10288675, 0.36227089, 0.10288675, 0.21956813, 0.21865492,
#         0.10288675, 0.10288675, 0.10288675, 0.10288675, 0.10288675]),
#  'mean_test_precision_macro': array([0.08881451, 0.33203994, 0.08881451, 0.26977854, 0.25031385,
#         0.08881451, 0.08881451, 0.08881451, 0.08881451, 0.08881451]),
#  'std_test_precision_macro': array([0.01407224, 0.03023095, 0.01407224, 0.05021041, 0.03165894,
#         0.01407224, 0.01407224, 0.01407224, 0.01407224, 0.01407224]),
#  'rank_test_precision_macro': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_recall_micro': array([0.27395412, 0.32118758, 0.27395412, 0.29554656, 0.24966262,
#         0.27395412, 0.27395412, 0.27395412, 0.27395412, 0.27395412]),
#  'split1_test_recall_micro': array([0.41554559, 0.45142003, 0.41554559, 0.43946188, 0.44544096,
#         0.41554559, 0.41554559, 0.41554559, 0.41554559, 0.41554559]),
#  'mean_test_recall_micro': array([0.34474985, 0.38630381, 0.34474985, 0.36750422, 0.34755179,
#         0.34474985, 0.34474985, 0.34474985, 0.34474985, 0.34474985]),
#  'std_test_recall_micro': array([0.07079574, 0.06511622, 0.07079574, 0.07195766, 0.09788917,
#         0.07079574, 0.07079574, 0.07079574, 0.07079574, 0.07079574]),
#  'rank_test_recall_micro': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32),
#  'split0_test_recall_macro': array([0.14285714, 0.1830376 , 0.14285714, 0.16747744, 0.13767687,
#         0.14285714, 0.14285714, 0.14285714, 0.14285714, 0.14285714]),
#  'split1_test_recall_macro': array([0.21428571, 0.25286187, 0.21428571, 0.24031518, 0.24126299,
#         0.21428571, 0.21428571, 0.21428571, 0.21428571, 0.21428571]),
#  'mean_test_recall_macro': array([0.17857143, 0.21794974, 0.17857143, 0.20389631, 0.18946993,
#         0.17857143, 0.17857143, 0.17857143, 0.17857143, 0.17857143]),
#  'std_test_recall_macro': array([0.03571429, 0.03491214, 0.03571429, 0.03641887, 0.05179306,
#         0.03571429, 0.03571429, 0.03571429, 0.03571429, 0.03571429]),
#  'rank_test_recall_macro': array([4, 1, 4, 2, 3, 4, 4, 4, 4, 4], dtype=int32)}

# %%
a = pd.DataFrame(model_performance['estimator'][0].cv_results_)
a
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.024796      0.000499         0.026907        0.001548
# 1       0.022196      0.000960         0.023957        0.001274
# 2       0.019843      0.000333         0.024559        0.001668
# 3       0.023337      0.000921         0.029217        0.002111
# 4       0.022016      0.000064         0.027822        0.002454
# 5       0.019391      0.000604         0.023609        0.000736
# 6       0.017673      0.000115         0.022433        0.000376
# 7       0.020107      0.001608         0.025043        0.001235
# 8       0.017614      0.000649         0.024648        0.000934
# 9       0.018714      0.001204         0.025016        0.001513
#
#   param_estimator__C param_estimator__gamma  \
# 0           0.226226               0.041095
# 1         730.080254               0.000381
# 2           0.225737               0.006832
# 3           8.631638               0.022478
# 4           2.995993               0.026783
# 5           0.216176               0.003754
# 6           0.308084               0.000688
# 7           0.074103               0.000896
# 8           0.010271               0.007508
# 9            1.56193               0.000564
#
#                                               params  split0_test_f1_micro  \
# 0  {'estimator__C': 0.22622573283031963, 'estimat...              0.359610
# 1  {'estimator__C': 730.0802536296363, 'estimator...              0.441968
# 2  {'estimator__C': 0.22573658804182628, 'estimat...              0.359610
# 3  {'estimator__C': 8.631637502243715, 'estimator...              0.421965
# 4  {'estimator__C': 2.995992829648104, 'estimator...              0.368526
# 5  {'estimator__C': 0.2161763105544836, 'estimato...              0.359610
# 6  {'estimator__C': 0.3080838358481395, 'estimato...              0.359610
# 7  {'estimator__C': 0.07410334600553543, 'estimat...              0.359610
# 8  {'estimator__C': 0.010270589297712174, 'estima...              0.359610
# 9  {'estimator__C': 1.5619304706549475, 'estimato...              0.359610
#
#    split1_test_f1_micro  mean_test_f1_micro  ...  split0_test_recall_micro  \
# 0              0.445513            0.402562  ...                  0.273954
# 1              0.521589            0.481779  ...                  0.321188
# 2              0.445513            0.402562  ...                  0.273954
# 3              0.512642            0.467303  ...                  0.295547
# 4              0.508099            0.438312  ...                  0.249663
# 5              0.445513            0.402562  ...                  0.273954
# 6              0.445513            0.402562  ...                  0.273954
# 7              0.445513            0.402562  ...                  0.273954
# 8              0.445513            0.402562  ...                  0.273954
# 9              0.445513            0.402562  ...                  0.273954
#
#    split1_test_recall_micro  mean_test_recall_micro  std_test_recall_micro  \
# 0                  0.415546                0.344750               0.070796
# 1                  0.451420                0.386304               0.065116
# 2                  0.415546                0.344750               0.070796
# 3                  0.439462                0.367504               0.071958
# 4                  0.445441                0.347552               0.097889
# 5                  0.415546                0.344750               0.070796
# 6                  0.415546                0.344750               0.070796
# 7                  0.415546                0.344750               0.070796
# 8                  0.415546                0.344750               0.070796
# 9                  0.415546                0.344750               0.070796
#
#    rank_test_recall_micro  split0_test_recall_macro  split1_test_recall_macro  \
# 0                       4                  0.142857                  0.214286
# 1                       1                  0.183038                  0.252862
# 2                       4                  0.142857                  0.214286
# 3                       2                  0.167477                  0.240315
# 4                       3                  0.137677                  0.241263
# 5                       4                  0.142857                  0.214286
# 6                       4                  0.142857                  0.214286
# 7                       4                  0.142857                  0.214286
# 8                       4                  0.142857                  0.214286
# 9                       4                  0.142857                  0.214286
#
#    mean_test_recall_macro  std_test_recall_macro  rank_test_recall_macro
# 0                0.178571               0.035714                       4
# 1                0.217950               0.034912                       1
# 2                0.178571               0.035714                       4
# 3                0.203896               0.036419                       2
# 4                0.189470               0.051793                       3
# 5                0.178571               0.035714                       4
# 6                0.178571               0.035714                       4
# 7                0.178571               0.035714                       4
# 8                0.178571               0.035714                       4
# 9                0.178571               0.035714                       4
#
# [10 rows x 42 columns]

# %%
a.iloc[0].params
# Out:
# {'estimator__C': 0.22622573283031963, 'estimator__gamma': 0.041094912743885305}

# %%
metrics_mean_cols = [col for col in results_df.columns if 'mean' in col]
metrics_std_cols = [col for col in results_df.columns if 'std' in col]

# %%
for mean_metric, std_metric in zip(metrics_mean_cols, metrics_std_cols):
    print(mean_metric, std_metric)
# Out:
# mean_fit_time std_fit_time
# mean_score_time std_score_time
# mean_test_f1_micro std_test_f1_micro
# mean_test_f1_macro std_test_f1_macro
# mean_test_accuracy std_test_accuracy
# mean_test_precision_micro std_test_precision_micro
# mean_test_precision_macro std_test_precision_macro
# mean_test_recall_micro std_test_recall_micro
# mean_test_recall_macro std_test_recall_macro

# %% [markdown]
# ### Classifier Chain

# %% [markdown]
# ### Classifiers that supports multilabel

# %%
clfs = {'ridge': RidgeClassifier(), 'rf': RandomForestClassifier()}

# %%
clf = RidgeClassifier()

# %%
clf.fit(X_train, y_train)

# %%
clf.predict(X_train)
